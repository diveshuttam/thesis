# %% [markdown]
# # Analysis fine bytes

# %%
import csv
from pprint import pprint

# %%
folder = "../../output/momon_data/bytes_fine"
momon1 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_momon_nrmse_with_param_momon_1-tcp.csv")))))
momon3 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_momon_nrmse_with_param_momon3-tcp.csv")))))
momon4 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_momon_nrmse_with_param_momon4-tcp.csv")))))

cemon1 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_cemon_nrmse_with_param_momon_1-tcp.csv")))))
cemon3 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_cemon_nrmse_with_param_momon3-tcp.csv")))))
cemon4 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_cemon_nrmse_with_param_momon4-tcp.csv")))))

# %%
print(len(momon1))
print(len(cemon1))
print(len(momon3))
print(len(cemon3))
print(len(momon4))
print(len(cemon4))
# Out:
# 5250
# 5250
# 5250
# 5250
# 5250
# 5250

# %% [markdown]
# # CeMon

# %%
ans=[]
def convert(m1_):
    m1 = [m1_[1]]+list(map(lambda x:round(float(x),3),[m1_[18],m1_[20],m1_[22],m1_[24],m1_[26],m1_[4],m1_[6],m1_[11],m1_[13]]))
    m1.extend([m1[-4]*m1[-2],m1[-3]*m1[-1]])
    m1.append(round(m1[-1]/m1[-2],3))
    return m1
    
for m1_,c1_,m3_,c3_,m4_,c4_ in zip(momon1,cemon1,momon3,cemon3,momon4,cemon4):
    # par = set(list(map(tuple,[m1[1:6],c1[1:6],m3[1:6],c3[1:6],m4[1:6],c4[1:6]])))
    # print(par, len(par))
    # assert(len(par)==1)
    # pprint(list(enumerate(m1_)))
    # m1.append(m1[])
    m1 = convert(m1_)
    c1 = convert(c1_)
    m4 = convert(m4_)
    c4 = convert(c4_)
    m3 = convert(m3_)
    c3 = convert(c3_)
    # pprint([m1,c1,m3,c3,m4,c4])
    m1=c1
    m3=c3
    m4=c4
    mi = min(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))
    avg = round(sum(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))/6,3)
    ans.append([m1[1:6], mi, avg])

# %% [markdown]
# ## Avg based cemon

# %%
pprint(list(sorted(ans, key=lambda x:-x[-1]))[:30])
# Out:
# [[[0.5, 3.0, 0.1, 1.8, 3.8], 0.778, 1.142],
#  [[0.5, 5.0, 0.1, 1.8, 2.6], 0.762, 1.083],
#  [[0.5, 3.0, 0.1, 1.5, 4.1], 0.926, 1.083],
#  [[0.5, 3.0, 0.1, 1.8, 3.0], 0.664, 1.08],
#  [[0.5, 5.0, 0.1, 1.8, 3.3], 0.736, 1.075],
#  [[0.5, 5.0, 0.5, 1.6, 4.5], 0.62, 1.073],
#  [[0.5, 3.0, 0.1, 1.8, 4.6], 0.785, 1.063],
#  [[0.5, 3.0, 0.1, 1.5, 3.6], 0.926, 1.063],
#  [[0.5, 3.0, 0.1, 2.5, 4.4], 0.778, 1.061],
#  [[0.5, 3.0, 0.2, 1.5, 1.5], 0.799, 1.061],
#  [[0.5, 5.0, 0.2, 2.0, 1.5], 0.721, 1.059],
#  [[0.5, 5.0, 0.1, 2.2, 4.9], 0.736, 1.058],
#  [[0.5, 5.0, 0.1, 2.5, 4.9], 0.893, 1.054],
#  [[0.5, 3.0, 0.1, 1.8, 4.8], 0.736, 1.053],
#  [[0.5, 5.0, 0.1, 1.8, 3.9], 0.962, 1.052],
#  [[0.5, 5.0, 0.1, 1.9, 4.5], 0.818, 1.051],
#  [[0.5, 3.0, 0.1, 2.4, 4.0], 0.799, 1.044],
#  [[0.5, 5.0, 0.1, 1.5, 2.3], 0.993, 1.041],
#  [[0.5, 3.0, 0.1, 1.9, 3.7], 0.499, 1.04],
#  [[0.5, 3.0, 0.1, 1.8, 4.5], 0.685, 1.039],
#  [[0.5, 5.0, 0.1, 2.2, 3.8], 0.924, 1.039],
#  [[0.5, 3.0, 0.1, 1.9, 4.6], 0.657, 1.037],
#  [[0.5, 5.0, 0.1, 1.8, 3.4], 0.806, 1.036],
#  [[0.5, 5.0, 0.1, 2.2, 4.4], 0.777, 1.035],
#  [[0.5, 3.0, 0.1, 1.5, 3.9], 0.862, 1.034],
#  [[0.5, 5.0, 0.5, 2.9, 4.2], 0.551, 1.034],
#  [[0.5, 5.0, 0.1, 1.8, 4.0], 0.682, 1.032],
#  [[0.5, 3.0, 0.1, 2.0, 4.1], 0.862, 1.032],
#  [[0.5, 3.0, 0.1, 1.5, 2.3], 0.862, 1.031],
#  [[0.5, 5.0, 0.1, 1.9, 4.1], 0.926, 1.03]]

# %% [markdown]
# ## Min based cemon

# %%
pprint(list(sorted(ans, key= lambda x:-x[-2]))[:60])
# Out:
# [[[0.5, 5.0, 0.1, 1.5, 2.3], 0.993, 1.041],
#  [[0.5, 5.0, 0.1, 2.4, 4.7], 0.962, 1.02],
#  [[0.5, 3.0, 0.1, 1.5, 2.4], 0.962, 1.024],
#  [[0.5, 5.0, 0.1, 1.8, 3.9], 0.962, 1.052],
#  [[0.5, 3.0, 0.1, 1.5, 4.1], 0.926, 1.083],
#  [[0.5, 3.0, 0.1, 1.5, 3.6], 0.926, 1.063],
#  [[0.5, 5.0, 0.1, 1.9, 4.1], 0.926, 1.03],
#  [[0.5, 5.0, 0.1, 2.4, 2.7], 0.924, 1.008],
#  [[0.5, 5.0, 0.1, 2.2, 3.8], 0.924, 1.039],
#  [[0.5, 3.0, 0.1, 1.5, 3.8], 0.896, 0.954],
#  [[0.5, 5.0, 0.1, 2.1, 4.7], 0.893, 0.958],
#  [[0.5, 5.0, 0.1, 2.5, 4.9], 0.893, 1.054],
#  [[0.5, 5.0, 0.1, 2.0, 3.3], 0.893, 1.016],
#  [[0.5, 5.0, 0.1, 2.1, 3.4], 0.893, 0.989],
#  [[0.5, 3.0, 0.1, 1.5, 4.5], 0.893, 0.984],
#  [[0.5, 3.0, 0.1, 1.7, 3.9], 0.893, 0.966],
#  [[0.5, 5.0, 0.1, 1.5, 2.2], 0.893, 0.93],
#  [[0.5, 3.0, 0.1, 2.4, 4.2], 0.874, 1.018],
#  [[0.5, 5.0, 0.1, 1.7, 3.8], 0.869, 0.999],
#  [[0.5, 3.0, 0.1, 2.0, 4.1], 0.862, 1.032],
#  [[0.5, 5.0, 0.1, 2.2, 4.5], 0.862, 1.018],
#  [[0.5, 3.0, 0.1, 1.5, 3.9], 0.862, 1.034],
#  [[0.5, 3.0, 0.1, 1.5, 2.3], 0.862, 1.031],
#  [[0.5, 3.0, 0.1, 1.6, 4.3], 0.857, 0.968],
#  [[0.5, 3.0, 0.1, 1.7, 4.1], 0.857, 0.965],
#  [[0.5, 3.0, 0.1, 2.0, 2.6], 0.847, 0.973],
#  [[0.5, 3.0, 0.1, 1.7, 4.8], 0.844, 0.861],
#  [[0.5, 5.0, 0.1, 1.8, 4.4], 0.844, 0.947],
#  [[0.5, 3.0, 0.1, 1.8, 2.3], 0.835, 1.004],
#  [[0.5, 3.0, 0.1, 1.5, 1.7], 0.833, 0.853],
#  [[0.5, 3.0, 0.1, 1.5, 4.6], 0.833, 0.959],
#  [[0.5, 3.0, 0.1, 1.7, 4.5], 0.833, 0.954],
#  [[0.5, 5.0, 0.1, 1.5, 4.1], 0.833, 0.993],
#  [[0.5, 5.0, 0.1, 1.7, 3.5], 0.833, 0.881],
#  [[0.5, 5.0, 0.1, 2.4, 3.8], 0.821, 1.023],
#  [[0.5, 5.0, 0.1, 2.8, 4.8], 0.821, 0.967],
#  [[0.5, 5.0, 0.1, 2.0, 2.3], 0.821, 0.955],
#  [[0.5, 3.0, 0.1, 1.6, 3.7], 0.821, 0.879],
#  [[0.5, 5.0, 0.1, 1.9, 4.5], 0.818, 1.051],
#  [[0.5, 5.0, 0.1, 2.0, 2.8], 0.818, 0.905],
#  [[0.5, 3.0, 0.1, 1.5, 1.8], 0.818, 0.937],
#  [[0.5, 5.0, 0.1, 1.7, 3.6], 0.814, 0.905],
#  [[0.5, 3.0, 0.1, 1.8, 2.6], 0.809, 0.998],
#  [[0.5, 5.0, 0.1, 2.4, 2.9], 0.809, 0.992],
#  [[0.5, 5.0, 0.1, 1.8, 3.0], 0.809, 1.025],
#  [[0.5, 5.0, 0.1, 2.2, 3.9], 0.809, 0.908],
#  [[0.5, 5.0, 0.1, 2.3, 4.1], 0.809, 1.018],
#  [[0.5, 5.0, 0.1, 1.8, 3.4], 0.806, 1.036],
#  [[0.5, 5.0, 0.1, 2.1, 3.5], 0.806, 0.885],
#  [[0.5, 3.0, 0.1, 1.5, 2.6], 0.806, 0.943],
#  [[0.5, 5.0, 0.1, 2.6, 3.8], 0.806, 0.941],
#  [[0.5, 5.0, 0.1, 2.3, 4.8], 0.806, 1.007],
#  [[0.5, 5.0, 0.1, 2.9, 4.7], 0.806, 0.941],
#  [[0.5, 3.0, 0.1, 1.6, 4.5], 0.806, 0.858],
#  [[0.5, 3.0, 0.1, 1.7, 2.6], 0.806, 0.925],
#  [[0.5, 5.0, 0.1, 1.7, 2.7], 0.806, 0.919],
#  [[0.5, 5.0, 0.1, 2.0, 4.4], 0.806, 0.862],
#  [[0.5, 5.0, 0.1, 1.7, 3.1], 0.806, 0.94],
#  [[0.5, 5.0, 0.1, 1.6, 3.8], 0.8, 0.875],
#  [[0.5, 5.0, 0.1, 2.9, 2.8], 0.8, 0.941]]

# %% [markdown]
# # Momon

# %%
ans=[]
def convert(m1_):
    m1 = [m1_[1]]+list(map(lambda x:round(float(x),3),[m1_[18],m1_[20],m1_[22],m1_[24],m1_[26],m1_[4],m1_[6],m1_[11],m1_[13]]))
    m1.extend([m1[-4]*m1[-2],m1[-3]*m1[-1]])
    m1.append(round(m1[-1]/m1[-2],3))
    return m1
    
for m1_,c1_,m3_,c3_,m4_,c4_ in zip(momon1,cemon1,momon3,cemon3,momon4,cemon4):
    # par = set(list(map(tuple,[m1[1:6],c1[1:6],m3[1:6],c3[1:6],m4[1:6],c4[1:6]])))
    # print(par, len(par))
    # assert(len(par)==1)
    # pprint(list(enumerate(m1_)))
    # m1.append(m1[])
    m1 = convert(m1_)
    c1 = convert(c1_)
    m4 = convert(m4_)
    c4 = convert(c4_)
    m3 = convert(m3_)
    c3 = convert(c3_)
    # pprint([m1,c1,m3,c3,m4,c4])
    c1=m1
    c3=m3
    c4=m4
    mi = min(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))
    avg = round(sum(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))/6,3)
    ans.append([m1[1:6], mi, avg])

# %% [markdown]
# ## Avg based momon

# %%
pprint(list(sorted(ans, key=lambda x:-x[-1]))[:30])
# Out:
# [[[0.5, 3.0, 0.5, 2.3, 3.5], 0.39, 4.203],
#  [[0.5, 3.0, 0.5, 2.0, 4.5], 0.405, 4.188],
#  [[0.5, 3.0, 0.2, 2.6, 3.5], 0.301, 4.174],
#  [[0.5, 3.0, 0.2, 2.6, 3.6], 0.301, 4.174],
#  [[0.5, 3.0, 0.2, 2.6, 3.7], 0.301, 4.174],
#  [[0.5, 3.0, 0.2, 2.6, 3.8], 0.301, 4.174],
#  [[0.5, 3.0, 0.2, 2.6, 4.0], 0.301, 4.174],
#  [[0.5, 3.0, 0.3, 2.9, 4.1], 0.27, 4.169],
#  [[0.5, 3.0, 0.5, 1.5, 3.8], 0.439, 4.138],
#  [[0.5, 3.0, 0.3, 2.3, 3.4], 0.351, 4.108],
#  [[0.5, 3.0, 0.4, 2.0, 3.7], 0.39, 4.091],
#  [[0.5, 3.0, 0.5, 2.1, 4.4], 0.405, 4.088],
#  [[0.5, 3.0, 0.5, 2.2, 4.0], 0.405, 4.088],
#  [[0.5, 3.0, 0.5, 2.2, 4.1], 0.405, 4.088],
#  [[0.5, 3.0, 0.5, 2.3, 4.7], 0.39, 4.083],
#  [[0.5, 3.0, 0.3, 2.5, 3.0], 0.329, 4.082],
#  [[0.5, 3.0, 0.5, 1.9, 3.1], 0.421, 4.077],
#  [[0.5, 3.0, 0.5, 1.9, 4.2], 0.421, 4.077],
#  [[0.5, 3.0, 0.5, 1.9, 4.6], 0.421, 4.077],
#  [[0.5, 3.0, 0.5, 1.8, 4.0], 0.421, 4.074],
#  [[0.5, 3.0, 0.5, 1.8, 4.1], 0.421, 4.074],
#  [[0.5, 3.0, 0.4, 1.6, 4.3], 0.405, 4.072],
#  [[0.5, 3.0, 0.3, 1.8, 4.7], 0.405, 4.072],
#  [[0.5, 3.0, 0.5, 1.9, 3.6], 0.421, 4.07],
#  [[0.5, 3.0, 0.5, 1.9, 4.8], 0.421, 4.07],
#  [[0.5, 3.0, 0.3, 1.5, 3.4], 0.421, 4.07],
#  [[0.5, 3.0, 0.4, 1.9, 4.7], 0.39, 4.067],
#  [[0.5, 3.0, 0.3, 1.8, 4.4], 0.405, 4.065],
#  [[0.5, 3.0, 0.3, 2.5, 3.9], 0.329, 4.062],
#  [[0.5, 3.0, 0.5, 2.6, 3.3], 0.376, 4.062]]

# %% [markdown]
# ## Min based momon

# %%
pprint(list(sorted(ans, key=lambda x:-x[-2]))[:30])
# Out:
# [[[0.5, 5.0, 0.1, 2.6, 4.5], 2.161, 2.768],
#  [[0.5, 3.0, 0.1, 1.9, 2.5], 2.138, 2.255],
#  [[0.5, 3.0, 0.1, 1.9, 3.7], 2.107, 2.176],
#  [[0.5, 5.0, 0.1, 2.5, 4.5], 2.056, 2.917],
#  [[0.5, 5.0, 0.1, 2.6, 4.2], 2.056, 2.913],
#  [[0.5, 5.0, 0.1, 1.9, 3.2], 2.049, 2.491],
#  [[0.5, 5.0, 0.2, 2.0, 1.5], 2.049, 2.826],
#  [[0.5, 5.0, 0.1, 2.0, 3.4], 2.007, 2.367],
#  [[0.5, 3.0, 0.1, 1.8, 3.0], 2.007, 2.614],
#  [[0.5, 5.0, 0.1, 2.9, 4.3], 2.007, 2.082],
#  [[0.5, 5.0, 0.1, 2.7, 4.4], 2.007, 2.542],
#  [[0.5, 5.0, 0.1, 1.9, 3.4], 1.987, 2.589],
#  [[0.5, 5.0, 0.1, 1.8, 3.3], 1.987, 2.906],
#  [[0.5, 5.0, 0.1, 2.8, 4.7], 1.967, 2.256],
#  [[0.5, 5.0, 0.1, 2.2, 3.6], 1.96, 2.568],
#  [[0.5, 5.0, 0.1, 2.8, 4.2], 1.941, 2.522],
#  [[0.5, 3.0, 0.1, 2.8, 4.7], 1.928, 2.215],
#  [[0.5, 3.0, 0.1, 1.9, 3.4], 1.916, 2.34],
#  [[0.5, 5.0, 0.1, 2.0, 2.9], 1.916, 2.389],
#  [[0.5, 3.0, 0.1, 2.0, 4.0], 1.916, 2.25],
#  [[0.5, 3.0, 0.1, 1.9, 4.8], 1.916, 2.097],
#  [[0.5, 5.0, 0.1, 2.8, 4.6], 1.903, 2.349],
#  [[0.5, 5.0, 0.1, 1.8, 3.7], 1.903, 2.381],
#  [[0.5, 3.0, 0.1, 1.9, 4.4], 1.873, 2.152],
#  [[0.5, 3.0, 0.1, 2.0, 3.3], 1.873, 2.213],
#  [[0.5, 5.0, 0.1, 2.4, 3.7], 1.873, 2.196],
#  [[0.5, 3.0, 0.1, 2.2, 4.8], 1.873, 2.373],
#  [[0.5, 3.0, 0.1, 1.9, 3.8], 1.873, 2.246],
#  [[0.5, 5.0, 0.1, 2.9, 3.9], 1.873, 2.258],
#  [[0.5, 5.0, 0.1, 2.0, 3.7], 1.873, 1.998]]

# %% [markdown]
# # Overall

# %%
ans=[]
def convert(m1_):
    m1 = [m1_[1]]+list(map(lambda x:round(float(x),3),[m1_[18],m1_[20],m1_[22],m1_[24],m1_[26],m1_[4],m1_[6],m1_[11],m1_[13]]))
    m1.extend([m1[-4]*m1[-2],m1[-3]*m1[-1]])
    m1.append(round(m1[-1]/m1[-2],3))
    return m1
    
for m1_,c1_,m3_,c3_,m4_,c4_ in zip(momon1,cemon1,momon3,cemon3,momon4,cemon4):
    # par = set(list(map(tuple,[m1[1:6],c1[1:6],m3[1:6],c3[1:6],m4[1:6],c4[1:6]])))
    # print(par, len(par))
    # assert(len(par)==1)
    # pprint(list(enumerate(m1_)))
    # m1.append(m1[])
    m1 = convert(m1_)
    c1 = convert(c1_)
    m4 = convert(m4_)
    c4 = convert(c4_)
    m3 = convert(m3_)
    c3 = convert(c3_)
    # pprint([m1,c1,m3,c3,m4,c4])
    mi = min(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))
    avg = round(sum(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))/6,3)
    ans.append([m1[1:6], mi, avg])

# %% [markdown]
# ## Avg based overall

# %%
pprint(list(sorted(ans, key=lambda x:-x[-1]))[:400])
# Out:
# [[[0.5, 3.0, 0.5, 2.3, 3.5], 0.357, 2.583],
#  [[0.5, 3.0, 0.5, 2.0, 4.5], 0.371, 2.576],
#  [[0.5, 3.0, 0.2, 2.6, 3.5], 0.276, 2.555],
#  [[0.5, 3.0, 0.2, 2.6, 3.6], 0.276, 2.555],
#  [[0.5, 3.0, 0.2, 2.6, 3.7], 0.276, 2.555],
#  [[0.5, 3.0, 0.2, 2.6, 3.8], 0.276, 2.555],
#  [[0.5, 3.0, 0.2, 2.6, 4.0], 0.276, 2.555],
#  [[0.5, 3.0, 0.3, 2.9, 4.1], 0.247, 2.55],
#  [[0.5, 3.0, 0.5, 1.5, 3.8], 0.402, 2.55],
#  [[0.5, 3.0, 0.3, 2.3, 3.4], 0.321, 2.522],
#  [[0.5, 3.0, 0.5, 2.1, 4.4], 0.371, 2.516],
#  [[0.5, 3.0, 0.5, 2.2, 4.0], 0.371, 2.516],
#  [[0.5, 3.0, 0.5, 2.2, 4.1], 0.371, 2.516],
#  [[0.5, 3.0, 0.4, 2.0, 3.7], 0.357, 2.514],
#  [[0.5, 3.0, 0.5, 1.9, 3.1], 0.386, 2.512],
#  [[0.5, 3.0, 0.5, 1.9, 4.2], 0.386, 2.512],
#  [[0.5, 3.0, 0.5, 1.9, 4.6], 0.386, 2.512],
#  [[0.5, 3.0, 0.5, 2.3, 4.7], 0.357, 2.511],
#  [[0.5, 3.0, 0.5, 1.8, 4.0], 0.386, 2.509],
#  [[0.5, 3.0, 0.5, 1.8, 4.1], 0.386, 2.509],
#  [[0.5, 3.0, 0.4, 1.6, 4.3], 0.371, 2.507],
#  [[0.5, 3.0, 0.3, 1.8, 4.7], 0.371, 2.507],
#  [[0.5, 3.0, 0.5, 1.9, 3.6], 0.386, 2.506],
#  [[0.5, 3.0, 0.5, 1.9, 4.8], 0.386, 2.506],
#  [[0.5, 3.0, 0.3, 1.5, 3.4], 0.386, 2.506],
#  [[0.5, 3.0, 0.3, 2.5, 3.0], 0.301, 2.505],
#  [[0.5, 3.0, 0.4, 1.9, 4.7], 0.357, 2.502],
#  [[0.5, 3.0, 0.3, 1.8, 4.4], 0.371, 2.501],
#  [[0.5, 3.0, 0.5, 2.6, 3.3], 0.344, 2.498],
#  [[0.5, 5.0, 0.5, 1.6, 4.5], 0.62, 2.495],
#  [[0.5, 3.0, 0.3, 2.5, 3.9], 0.301, 2.491],
#  [[0.5, 3.0, 0.4, 2.9, 4.6], 0.344, 2.49],
#  [[0.5, 3.0, 0.4, 2.9, 4.5], 0.344, 2.488],
#  [[0.5, 3.0, 0.4, 2.4, 3.4], 0.333, 2.488],
#  [[0.5, 3.0, 0.4, 2.5, 4.6], 0.301, 2.483],
#  [[0.5, 5.0, 0.4, 1.5, 3.0], 0.471, 2.483],
#  [[0.5, 3.0, 0.4, 2.2, 3.0], 0.321, 2.482],
#  [[0.5, 5.0, 0.3, 2.3, 3.0], 0.37, 2.482],
#  [[0.5, 3.0, 0.4, 1.5, 3.9], 0.402, 2.481],
#  [[0.5, 5.0, 0.3, 2.0, 2.9], 0.386, 2.477],
#  [[0.5, 3.0, 0.5, 1.6, 3.2], 0.386, 2.475],
#  [[0.5, 3.0, 0.5, 1.8, 3.2], 0.386, 2.471],
#  [[0.5, 3.0, 0.5, 1.8, 3.5], 0.386, 2.471],
#  [[0.5, 3.0, 0.4, 1.8, 4.9], 0.371, 2.47],
#  [[0.5, 3.0, 0.4, 1.8, 4.0], 0.371, 2.466],
#  [[0.5, 5.0, 0.2, 1.7, 3.0], 0.407, 2.459],
#  [[0.5, 5.0, 0.3, 1.5, 2.8], 0.426, 2.459],
#  [[0.5, 3.0, 0.5, 2.1, 4.9], 0.371, 2.458],
#  [[0.5, 3.0, 0.5, 2.2, 2.9], 0.358, 2.454],
#  [[0.5, 3.0, 0.5, 2.3, 3.1], 0.357, 2.453],
#  [[0.5, 3.0, 0.5, 2.3, 3.9], 0.357, 2.453],
#  [[0.5, 3.0, 0.5, 2.2, 3.2], 0.371, 2.452],
#  [[0.5, 5.0, 0.4, 1.6, 2.8], 0.409, 2.452],
#  [[0.5, 3.0, 0.3, 2.3, 3.1], 0.321, 2.449],
#  [[0.5, 5.0, 0.2, 2.3, 3.0], 0.326, 2.447],
#  [[0.5, 3.0, 0.5, 2.1, 3.8], 0.371, 2.447],
#  [[0.5, 3.0, 0.5, 2.3, 4.1], 0.357, 2.447],
#  [[0.5, 5.0, 0.4, 2.6, 4.1], 0.483, 2.446],
#  [[0.5, 3.0, 0.5, 2.0, 4.6], 0.371, 2.446],
#  [[0.5, 3.0, 0.4, 1.6, 4.4], 0.371, 2.446],
#  [[0.5, 5.0, 0.3, 2.4, 2.8], 0.299, 2.443],
#  [[0.5, 3.0, 0.4, 2.2, 2.8], 0.316, 2.439],
#  [[0.5, 3.0, 0.5, 1.7, 3.1], 0.386, 2.437],
#  [[0.5, 3.0, 0.5, 1.9, 3.7], 0.386, 2.437],
#  [[0.5, 3.0, 0.5, 1.9, 4.5], 0.386, 2.437],
#  [[0.5, 3.0, 0.5, 1.9, 4.9], 0.386, 2.437],
#  [[0.5, 3.0, 0.3, 1.5, 3.0], 0.386, 2.437],
#  [[0.5, 3.0, 0.3, 1.5, 3.5], 0.386, 2.437],
#  [[0.5, 3.0, 0.5, 2.6, 4.1], 0.344, 2.436],
#  [[0.5, 3.0, 0.5, 2.0, 4.2], 0.371, 2.432],
#  [[0.5, 3.0, 0.3, 1.8, 4.6], 0.371, 2.432],
#  [[0.5, 5.0, 0.5, 2.9, 4.2], 0.551, 2.431],
#  [[0.5, 3.0, 0.4, 2.9, 4.7], 0.344, 2.43],
#  [[0.5, 3.0, 0.3, 2.9, 3.4], 0.247, 2.428],
#  [[0.5, 3.0, 0.2, 2.0, 4.0], 0.301, 2.427],
#  [[0.5, 5.0, 0.4, 1.7, 2.9], 0.429, 2.427],
#  [[0.5, 3.0, 0.2, 2.3, 3.7], 0.311, 2.425],
#  [[0.5, 5.0, 0.5, 1.7, 3.0], 0.437, 2.425],
#  [[0.5, 3.0, 0.5, 2.6, 4.0], 0.344, 2.423],
#  [[0.5, 3.0, 0.4, 2.4, 3.7], 0.333, 2.421],
#  [[0.5, 5.0, 0.5, 1.6, 2.9], 0.422, 2.42],
#  [[0.5, 3.0, 0.2, 2.2, 2.8], 0.26, 2.42],
#  [[0.5, 3.0, 0.4, 1.5, 3.0], 0.402, 2.419],
#  [[0.5, 3.0, 0.4, 1.5, 4.0], 0.402, 2.419],
#  [[0.5, 3.0, 0.5, 1.5, 4.7], 0.402, 2.419],
#  [[0.5, 3.0, 0.3, 2.6, 2.8], 0.253, 2.417],
#  [[0.5, 3.0, 0.5, 2.5, 4.5], 0.357, 2.415],
#  [[0.5, 3.0, 0.3, 2.7, 3.2], 0.321, 2.415],
#  [[0.5, 3.0, 0.2, 2.6, 4.6], 0.276, 2.414],
#  [[0.5, 3.0, 0.4, 1.5, 4.9], 0.402, 2.413],
#  [[0.5, 3.0, 0.5, 1.5, 4.9], 0.402, 2.413],
#  [[0.5, 3.0, 0.5, 1.6, 3.0], 0.386, 2.413],
#  [[0.5, 3.0, 0.5, 1.6, 4.2], 0.386, 2.413],
#  [[0.5, 3.0, 0.5, 1.6, 4.3], 0.386, 2.413],
#  [[0.5, 3.0, 0.2, 2.3, 3.0], 0.311, 2.411],
#  [[0.5, 3.0, 0.3, 2.9, 4.0], 0.247, 2.409],
#  [[0.5, 5.0, 0.4, 1.5, 4.3], 0.583, 2.408],
#  [[0.5, 3.0, 0.4, 1.5, 3.7], 0.402, 2.408],
#  [[0.5, 3.0, 0.4, 1.5, 4.4], 0.402, 2.408],
#  [[0.5, 3.0, 0.4, 1.5, 4.5], 0.402, 2.408],
#  [[0.5, 3.0, 0.5, 1.5, 3.3], 0.402, 2.408],
#  [[0.5, 3.0, 0.5, 1.5, 3.4], 0.402, 2.408],
#  [[0.5, 5.0, 0.2, 1.5, 3.0], 0.444, 2.404],
#  [[0.5, 5.0, 0.5, 1.8, 3.0], 0.444, 2.404],
#  [[0.5, 3.0, 0.5, 1.6, 3.8], 0.386, 2.402],
#  [[0.5, 3.0, 0.5, 1.6, 4.8], 0.386, 2.402],
#  [[0.5, 3.0, 0.4, 1.8, 3.1], 0.371, 2.397],
#  [[0.5, 3.0, 0.4, 1.8, 3.8], 0.371, 2.397],
#  [[0.5, 3.0, 0.4, 1.8, 3.9], 0.371, 2.397],
#  [[0.5, 3.0, 0.4, 1.8, 4.5], 0.371, 2.397],
#  [[0.5, 3.0, 0.4, 1.8, 4.6], 0.371, 2.397],
#  [[0.5, 5.0, 0.2, 1.9, 3.0], 0.4, 2.397],
#  [[0.5, 5.0, 0.4, 2.3, 4.3], 0.551, 2.396],
#  [[0.5, 3.0, 0.5, 1.9, 3.4], 0.386, 2.396],
#  [[0.5, 3.0, 0.5, 1.9, 4.3], 0.386, 2.396],
#  [[0.5, 3.0, 0.3, 1.5, 3.1], 0.386, 2.396],
#  [[0.5, 5.0, 0.2, 1.8, 2.8], 0.35, 2.396],
#  [[0.5, 5.0, 0.3, 1.8, 3.0], 0.421, 2.395],
#  [[0.5, 5.0, 0.4, 2.1, 3.0], 0.421, 2.395],
#  [[0.5, 3.0, 0.5, 2.2, 4.3], 0.371, 2.394],
#  [[0.5, 3.0, 0.2, 2.9, 3.9], 0.261, 2.394],
#  [[0.5, 5.0, 0.4, 2.4, 3.0], 0.4, 2.394],
#  [[0.5, 3.0, 0.3, 2.3, 3.5], 0.321, 2.391],
#  [[0.5, 3.0, 0.4, 2.5, 3.0], 0.301, 2.39],
#  [[0.5, 5.0, 0.5, 1.5, 2.8], 0.426, 2.39],
#  [[0.5, 5.0, 0.4, 2.7, 3.0], 0.381, 2.389],
#  [[0.5, 5.0, 0.3, 2.6, 2.9], 0.336, 2.387],
#  [[0.5, 5.0, 0.4, 2.8, 2.9], 0.322, 2.386],
#  [[0.5, 3.0, 0.5, 1.5, 2.8], 0.354, 2.386],
#  [[0.5, 3.0, 0.5, 2.2, 4.7], 0.371, 2.385],
#  [[0.5, 5.0, 0.5, 1.6, 2.8], 0.409, 2.384],
#  [[0.5, 3.0, 0.3, 1.8, 2.9], 0.345, 2.383],
#  [[0.5, 5.0, 0.5, 2.2, 2.8], 0.402, 2.381],
#  [[0.5, 5.0, 0.4, 2.9, 3.0], 0.381, 2.38],
#  [[0.5, 5.0, 0.5, 1.6, 3.0], 0.462, 2.38],
#  [[0.5, 3.0, 0.3, 2.3, 4.0], 0.321, 2.379],
#  [[0.5, 3.0, 0.3, 2.3, 4.1], 0.321, 2.379],
#  [[0.5, 3.0, 0.5, 2.5, 4.3], 0.357, 2.378],
#  [[0.5, 3.0, 0.5, 1.9, 3.2], 0.386, 2.376],
#  [[0.5, 3.0, 0.5, 1.9, 4.0], 0.386, 2.376],
#  [[0.5, 3.0, 0.3, 1.5, 3.6], 0.386, 2.376],
#  [[0.5, 5.0, 0.4, 2.1, 2.8], 0.387, 2.375],
#  [[0.5, 5.0, 0.5, 2.1, 2.8], 0.387, 2.375],
#  [[0.5, 3.0, 0.3, 2.4, 2.7], 0.222, 2.373],
#  [[0.5, 3.0, 0.3, 1.8, 4.2], 0.371, 2.371],
#  [[0.5, 5.0, 0.2, 2.6, 2.8], 0.283, 2.371],
#  [[0.5, 3.0, 0.2, 2.0, 4.2], 0.301, 2.37],
#  [[0.5, 5.0, 0.2, 2.5, 3.0], 0.354, 2.37],
#  [[0.5, 3.0, 0.5, 2.5, 3.9], 0.357, 2.369],
#  [[0.5, 3.0, 0.5, 1.8, 4.6], 0.386, 2.369],
#  [[0.5, 3.0, 0.5, 1.8, 4.9], 0.386, 2.369],
#  [[0.5, 3.0, 0.4, 2.2, 2.9], 0.316, 2.368],
#  [[0.5, 5.0, 0.4, 2.9, 2.9], 0.276, 2.368],
#  [[0.5, 5.0, 0.5, 2.5, 2.8], 0.368, 2.368],
#  [[0.5, 5.0, 0.5, 2.8, 2.8], 0.368, 2.368],
#  [[0.5, 5.0, 0.5, 2.9, 2.0], 0.297, 2.367],
#  [[0.5, 3.0, 0.4, 1.6, 3.1], 0.371, 2.366],
#  [[0.5, 3.0, 0.4, 1.6, 4.5], 0.371, 2.366],
#  [[0.5, 3.0, 0.3, 1.8, 4.3], 0.371, 2.366],
#  [[0.5, 3.0, 0.3, 1.8, 4.9], 0.371, 2.366],
#  [[0.5, 5.0, 0.2, 1.5, 2.9], 0.422, 2.365],
#  [[0.5, 3.0, 0.5, 1.5, 3.9], 0.402, 2.364],
#  [[0.5, 5.0, 0.4, 1.7, 3.0], 0.444, 2.362],
#  [[0.5, 5.0, 0.5, 2.4, 2.8], 0.35, 2.361],
#  [[0.5, 5.0, 0.4, 2.8, 2.8], 0.35, 2.361],
#  [[0.5, 5.0, 0.2, 1.7, 2.7], 0.364, 2.361],
#  [[0.5, 5.0, 0.4, 2.0, 2.9], 0.407, 2.359],
#  [[0.5, 3.0, 0.4, 2.6, 4.9], 0.344, 2.356],
#  [[0.5, 5.0, 0.3, 2.8, 2.8], 0.245, 2.356],
#  [[0.5, 5.0, 0.5, 1.5, 1.6], 0.545, 2.355],
#  [[0.5, 3.0, 0.5, 2.6, 2.7], 0.291, 2.355],
#  [[0.5, 5.0, 0.5, 2.7, 2.7], 0.345, 2.354],
#  [[0.5, 5.0, 0.3, 2.9, 4.0], 0.441, 2.353],
#  [[0.5, 3.0, 0.2, 2.4, 3.1], 0.284, 2.353],
#  [[0.5, 3.0, 0.2, 2.4, 3.2], 0.284, 2.353],
#  [[0.5, 3.0, 0.4, 1.8, 3.5], 0.371, 2.353],
#  [[0.5, 3.0, 0.4, 1.8, 3.6], 0.371, 2.353],
#  [[0.5, 5.0, 0.3, 1.6, 2.9], 0.422, 2.353],
#  [[0.5, 3.0, 0.4, 2.9, 2.9], 0.266, 2.351],
#  [[0.5, 3.0, 0.4, 2.0, 4.3], 0.357, 2.347],
#  [[0.5, 5.0, 0.2, 1.6, 2.9], 0.407, 2.347],
#  [[0.5, 3.0, 0.4, 2.5, 3.8], 0.301, 2.346],
#  [[0.5, 3.0, 0.5, 1.9, 3.0], 0.386, 2.346],
#  [[0.5, 5.0, 0.3, 2.2, 2.8], 0.374, 2.346],
#  [[0.5, 5.0, 0.4, 2.8, 2.0], 0.324, 2.346],
#  [[0.5, 3.0, 0.5, 2.2, 3.1], 0.371, 2.343],
#  [[0.5, 3.0, 0.4, 2.0, 3.8], 0.357, 2.343],
#  [[0.5, 5.0, 0.2, 1.6, 2.8], 0.393, 2.342],
#  [[0.5, 5.0, 0.3, 1.6, 2.8], 0.393, 2.342],
#  [[0.5, 3.0, 0.5, 1.6, 3.4], 0.386, 2.341],
#  [[0.5, 3.0, 0.5, 1.6, 3.5], 0.386, 2.341],
#  [[0.5, 5.0, 0.5, 2.0, 3.0], 0.444, 2.341],
#  [[0.5, 5.0, 0.5, 2.4, 2.9], 0.386, 2.339],
#  [[0.5, 3.0, 0.5, 2.3, 3.4], 0.357, 2.338],
#  [[0.5, 3.0, 0.5, 2.3, 4.4], 0.357, 2.338],
#  [[0.5, 5.0, 0.3, 2.1, 2.9], 0.351, 2.338],
#  [[0.5, 3.0, 0.2, 2.7, 2.8], 0.227, 2.337],
#  [[0.5, 3.0, 0.2, 2.9, 2.9], 0.212, 2.336],
#  [[0.5, 3.0, 0.2, 2.5, 2.7], 0.234, 2.336],
#  [[0.5, 3.0, 0.4, 1.8, 3.7], 0.371, 2.335],
#  [[0.5, 3.0, 0.4, 1.8, 4.1], 0.371, 2.335],
#  [[0.5, 5.0, 0.5, 2.3, 2.8], 0.374, 2.335],
#  [[0.5, 5.0, 0.5, 2.4, 4.0], 0.551, 2.334],
#  [[0.5, 5.0, 0.5, 2.6, 3.0], 0.421, 2.334],
#  [[0.5, 5.0, 0.4, 2.3, 3.0], 0.421, 2.334],
#  [[0.5, 5.0, 0.5, 2.3, 3.0], 0.421, 2.334],
#  [[0.5, 3.0, 0.4, 2.5, 3.1], 0.301, 2.333],
#  [[0.5, 5.0, 0.4, 2.2, 3.0], 0.421, 2.333],
#  [[0.5, 5.0, 0.3, 2.1, 3.0], 0.421, 2.333],
#  [[0.5, 5.0, 0.2, 2.9, 2.9], 0.197, 2.333],
#  [[0.5, 5.0, 0.2, 2.0, 2.8], 0.34, 2.333],
#  [[0.5, 3.0, 0.2, 2.9, 4.1], 0.261, 2.332],
#  [[0.5, 3.0, 0.5, 2.6, 4.3], 0.344, 2.332],
#  [[0.5, 3.0, 0.5, 2.1, 4.1], 0.371, 2.331],
#  [[0.5, 5.0, 0.5, 2.7, 2.9], 0.362, 2.33],
#  [[0.5, 5.0, 0.4, 1.5, 2.8], 0.426, 2.329],
#  [[0.5, 3.0, 0.3, 1.9, 3.7], 0.333, 2.328],
#  [[0.5, 3.0, 0.3, 1.9, 3.8], 0.333, 2.328],
#  [[0.5, 3.0, 0.5, 2.4, 3.0], 0.333, 2.328],
#  [[0.5, 3.0, 0.5, 2.4, 3.1], 0.333, 2.328],
#  [[0.5, 5.0, 0.3, 2.6, 3.0], 0.364, 2.328],
#  [[0.5, 5.0, 0.4, 2.5, 2.8], 0.325, 2.328],
#  [[0.5, 3.0, 0.5, 2.5, 4.6], 0.357, 2.326],
#  [[0.5, 3.0, 0.4, 1.8, 2.9], 0.352, 2.326],
#  [[0.5, 5.0, 0.3, 2.2, 2.0], 0.254, 2.326],
#  [[0.5, 5.0, 0.5, 2.4, 3.9], 0.533, 2.323],
#  [[0.5, 3.0, 0.5, 1.8, 4.3], 0.386, 2.323],
#  [[0.5, 3.0, 0.5, 2.0, 2.8], 0.34, 2.322],
#  [[0.5, 5.0, 0.2, 1.5, 2.8], 0.409, 2.322],
#  [[0.5, 3.0, 0.5, 2.5, 4.1], 0.357, 2.321],
#  [[0.5, 3.0, 0.5, 1.7, 3.7], 0.386, 2.321],
#  [[0.5, 3.0, 0.5, 1.7, 3.9], 0.386, 2.321],
#  [[0.5, 3.0, 0.5, 1.9, 4.1], 0.386, 2.321],
#  [[0.5, 3.0, 0.5, 1.9, 4.4], 0.386, 2.321],
#  [[0.5, 3.0, 0.3, 1.5, 3.3], 0.386, 2.321],
#  [[0.5, 3.0, 0.5, 1.8, 2.9], 0.366, 2.32],
#  [[0.5, 5.0, 0.3, 2.4, 2.9], 0.336, 2.32],
#  [[0.5, 3.0, 0.5, 1.8, 4.2], 0.386, 2.319],
#  [[0.5, 5.0, 0.4, 2.8, 3.0], 0.381, 2.318],
#  [[0.5, 3.0, 0.3, 2.4, 2.0], 0.256, 2.318],
#  [[0.5, 3.0, 0.3, 2.2, 3.1], 0.301, 2.317],
#  [[0.5, 3.0, 0.3, 2.2, 4.0], 0.301, 2.317],
#  [[0.5, 3.0, 0.3, 2.2, 4.1], 0.301, 2.317],
#  [[0.5, 3.0, 0.2, 1.5, 2.1], 0.273, 2.317],
#  [[0.5, 3.0, 0.5, 2.0, 4.1], 0.371, 2.315],
#  [[0.5, 3.0, 0.3, 1.8, 4.1], 0.371, 2.315],
#  [[0.5, 3.0, 0.3, 1.8, 4.5], 0.371, 2.315],
#  [[0.5, 3.0, 0.5, 1.5, 4.8], 0.402, 2.315],
#  [[0.5, 3.0, 0.4, 1.6, 2.8], 0.354, 2.315],
#  [[0.5, 5.0, 0.3, 1.8, 2.7], 0.339, 2.315],
#  [[0.5, 3.0, 0.4, 2.1, 2.9], 0.345, 2.312],
#  [[0.5, 3.0, 0.5, 1.9, 2.9], 0.345, 2.312],
#  [[0.5, 3.0, 0.2, 1.8, 2.1], 0.256, 2.312],
#  [[0.5, 3.0, 0.3, 1.5, 4.6], 0.386, 2.311],
#  [[0.5, 5.0, 0.3, 2.7, 3.0], 0.32, 2.311],
#  [[0.5, 3.0, 0.5, 2.5, 2.0], 0.234, 2.311],
#  [[0.5, 3.0, 0.4, 1.7, 2.8], 0.34, 2.31],
#  [[0.5, 3.0, 0.5, 1.9, 3.8], 0.386, 2.309],
#  [[0.5, 5.0, 0.5, 1.9, 2.8], 0.415, 2.309],
#  [[0.5, 5.0, 0.4, 2.5, 4.2], 0.483, 2.308],
#  [[0.5, 3.0, 0.4, 1.6, 2.7], 0.338, 2.308],
#  [[0.5, 5.0, 0.5, 1.9, 2.7], 0.39, 2.307],
#  [[0.5, 3.0, 0.5, 1.8, 4.5], 0.386, 2.306],
#  [[0.5, 5.0, 0.2, 2.4, 3.0], 0.308, 2.306],
#  [[0.5, 5.0, 0.2, 2.7, 3.0], 0.348, 2.306],
#  [[0.5, 5.0, 0.4, 1.6, 3.0], 0.462, 2.306],
#  [[0.5, 3.0, 0.4, 1.8, 2.8], 0.328, 2.306],
#  [[0.5, 5.0, 0.4, 2.6, 2.8], 0.299, 2.306],
#  [[0.5, 3.0, 0.3, 2.0, 2.8], 0.328, 2.306],
#  [[0.5, 5.0, 0.3, 1.6, 2.7], 0.39, 2.305],
#  [[0.5, 5.0, 0.5, 1.6, 2.0], 0.39, 2.305],
#  [[0.5, 5.0, 0.4, 1.5, 2.7], 0.39, 2.305],
#  [[0.5, 5.0, 0.5, 1.9, 4.0], 0.583, 2.304],
#  [[0.5, 3.0, 0.3, 1.7, 3.6], 0.344, 2.304],
#  [[0.5, 5.0, 0.5, 2.9, 2.8], 0.362, 2.304],
#  [[0.5, 5.0, 0.2, 2.3, 2.0], 0.297, 2.303],
#  [[0.5, 3.0, 0.5, 1.6, 2.0], 0.325, 2.303],
#  [[0.5, 3.0, 0.5, 1.6, 2.7], 0.338, 2.303],
#  [[0.5, 3.0, 0.5, 2.3, 3.2], 0.357, 2.302],
#  [[0.5, 3.0, 0.4, 2.4, 3.3], 0.333, 2.302],
#  [[0.5, 3.0, 0.2, 1.5, 3.8], 0.333, 2.302],
#  [[0.5, 3.0, 0.2, 1.6, 2.8], 0.316, 2.302],
#  [[0.5, 3.0, 0.5, 2.4, 2.8], 0.316, 2.302],
#  [[0.5, 5.0, 0.2, 2.3, 2.8], 0.288, 2.302],
#  [[0.5, 3.0, 0.2, 2.0, 2.8], 0.316, 2.302],
#  [[0.5, 3.0, 0.2, 2.1, 2.0], 0.209, 2.302],
#  [[0.5, 3.0, 0.5, 1.7, 3.6], 0.386, 2.301],
#  [[0.5, 3.0, 0.5, 1.9, 3.3], 0.386, 2.301],
#  [[0.5, 5.0, 0.2, 1.7, 2.8], 0.393, 2.301],
#  [[0.5, 5.0, 0.3, 1.7, 2.8], 0.393, 2.301],
#  [[0.5, 3.0, 0.2, 2.7, 2.7], 0.206, 2.301],
#  [[0.5, 5.0, 0.3, 2.2, 4.3], 0.511, 2.3],
#  [[0.5, 3.0, 0.5, 2.7, 2.9], 0.31, 2.3],
#  [[0.5, 5.0, 0.5, 2.7, 2.8], 0.35, 2.3],
#  [[0.5, 5.0, 0.5, 2.7, 1.6], 0.471, 2.299],
#  [[0.5, 3.0, 0.2, 2.3, 2.0], 0.206, 2.299],
#  [[0.5, 3.0, 0.4, 1.6, 2.0], 0.325, 2.299],
#  [[0.5, 3.0, 0.5, 2.2, 2.7], 0.325, 2.299],
#  [[0.5, 3.0, 0.3, 2.7, 3.1], 0.321, 2.298],
#  [[0.5, 5.0, 0.5, 1.9, 3.0], 0.471, 2.298],
#  [[0.5, 5.0, 0.5, 1.5, 3.0], 0.471, 2.298],
#  [[0.5, 3.0, 0.5, 1.6, 4.6], 0.386, 2.297],
#  [[0.5, 3.0, 0.3, 1.9, 2.8], 0.29, 2.297],
#  [[0.5, 5.0, 0.4, 1.9, 2.7], 0.369, 2.297],
#  [[0.5, 5.0, 0.5, 1.9, 2.0], 0.369, 2.297],
#  [[0.5, 3.0, 0.3, 1.7, 3.3], 0.344, 2.296],
#  [[0.5, 3.0, 0.3, 1.7, 3.4], 0.344, 2.296],
#  [[0.5, 3.0, 0.2, 2.4, 3.3], 0.284, 2.296],
#  [[0.5, 3.0, 0.4, 2.5, 2.9], 0.3, 2.296],
#  [[0.5, 5.0, 0.3, 2.3, 4.1], 0.461, 2.295],
#  [[0.5, 3.0, 0.5, 2.4, 2.7], 0.301, 2.295],
#  [[0.5, 3.0, 0.5, 1.5, 1.6], 0.491, 2.294],
#  [[0.5, 5.0, 0.4, 2.4, 2.8], 0.334, 2.294],
#  [[0.5, 3.0, 0.2, 1.5, 2.7], 0.312, 2.294],
#  [[0.5, 3.0, 0.3, 2.0, 4.3], 0.311, 2.293],
#  [[0.5, 3.0, 0.2, 2.1, 2.9], 0.291, 2.293],
#  [[0.5, 5.0, 0.5, 1.7, 4.5], 0.606, 2.292],
#  [[0.5, 3.0, 0.5, 2.3, 4.8], 0.357, 2.292],
#  [[0.5, 3.0, 0.5, 2.5, 3.7], 0.357, 2.292],
#  [[0.5, 5.0, 0.5, 2.3, 2.7], 0.351, 2.292],
#  [[0.5, 5.0, 0.4, 2.3, 2.7], 0.351, 2.292],
#  [[0.5, 3.0, 0.5, 1.5, 3.2], 0.402, 2.291],
#  [[0.5, 3.0, 0.5, 1.5, 4.3], 0.402, 2.291],
#  [[0.5, 5.0, 0.5, 2.7, 3.0], 0.414, 2.291],
#  [[0.5, 3.0, 0.2, 1.7, 2.7], 0.291, 2.291],
#  [[0.5, 3.0, 0.2, 1.9, 2.9], 0.282, 2.29],
#  [[0.5, 5.0, 0.2, 2.0, 2.7], 0.274, 2.29],
#  [[0.5, 5.0, 0.3, 2.1, 2.7], 0.351, 2.29],
#  [[0.5, 5.0, 0.4, 1.6, 2.0], 0.351, 2.29],
#  [[0.5, 5.0, 0.5, 1.8, 2.8], 0.409, 2.289],
#  [[0.5, 5.0, 0.3, 1.8, 2.9], 0.407, 2.288],
#  [[0.5, 3.0, 0.3, 2.4, 2.8], 0.277, 2.288],
#  [[0.5, 3.0, 0.2, 1.9, 2.8], 0.277, 2.288],
#  [[0.5, 3.0, 0.3, 2.2, 2.7], 0.281, 2.288],
#  [[0.5, 5.0, 0.5, 1.5, 4.1], 0.62, 2.287],
#  [[0.5, 5.0, 0.2, 2.9, 3.0], 0.296, 2.286],
#  [[0.5, 3.0, 0.2, 2.5, 2.9], 0.259, 2.286],
#  [[0.5, 5.0, 0.2, 1.5, 2.0], 0.334, 2.286],
#  [[0.5, 5.0, 0.4, 1.8, 2.0], 0.334, 2.286],
#  [[0.5, 5.0, 0.4, 1.9, 3.0], 0.444, 2.285],
#  [[0.5, 5.0, 0.5, 2.2, 2.0], 0.339, 2.285],
#  [[0.5, 5.0, 0.2, 2.2, 2.1], 0.165, 2.285],
#  [[0.5, 5.0, 0.5, 1.7, 2.8], 0.433, 2.283],
#  [[0.5, 3.0, 0.4, 1.5, 4.1], 0.402, 2.282],
#  [[0.5, 5.0, 0.5, 2.6, 2.9], 0.4, 2.282],
#  [[0.5, 5.0, 0.5, 2.8, 2.0], 0.324, 2.282],
#  [[0.5, 5.0, 0.4, 2.7, 2.7], 0.329, 2.281],
#  [[0.5, 5.0, 0.3, 1.9, 2.0], 0.329, 2.281],
#  [[0.5, 3.0, 0.4, 2.5, 4.0], 0.301, 2.28],
#  [[0.5, 3.0, 0.4, 1.8, 4.4], 0.371, 2.28],
#  [[0.5, 5.0, 0.3, 1.5, 3.0], 0.444, 2.28],
#  [[0.5, 3.0, 0.2, 2.3, 2.8], 0.253, 2.28],
#  [[0.5, 5.0, 0.3, 1.9, 2.8], 0.393, 2.28],
#  [[0.5, 5.0, 0.3, 1.9, 2.1], 0.324, 2.28],
#  [[0.5, 3.0, 0.4, 2.2, 3.5], 0.321, 2.279],
#  [[0.5, 3.0, 0.5, 2.7, 3.9], 0.321, 2.279],
#  [[0.5, 5.0, 0.5, 2.1, 3.0], 0.421, 2.279],
#  [[0.5, 3.0, 0.2, 2.6, 2.8], 0.246, 2.278],
#  [[0.5, 5.0, 0.3, 2.0, 2.7], 0.319, 2.278],
#  [[0.5, 5.0, 0.5, 2.5, 2.7], 0.319, 2.278],
#  [[0.5, 5.0, 0.2, 1.8, 2.0], 0.319, 2.278],
#  [[0.5, 3.0, 0.1, 1.7, 4.1], 0.857, 2.277],
#  [[0.5, 3.0, 0.2, 2.9, 4.0], 0.261, 2.277],
#  [[0.5, 5.0, 0.4, 2.2, 2.8], 0.374, 2.276],
#  [[0.5, 5.0, 0.3, 2.7, 2.7], 0.314, 2.276],
#  [[0.5, 3.0, 0.3, 2.3, 4.3], 0.321, 2.275],
#  [[0.5, 3.0, 0.3, 2.3, 4.7], 0.321, 2.275],
#  [[0.5, 5.0, 0.3, 2.5, 2.8], 0.325, 2.275],
#  [[0.5, 5.0, 0.3, 2.5, 2.9], 0.322, 2.274],
#  [[0.5, 3.0, 0.5, 1.7, 2.8], 0.354, 2.274],
#  [[0.5, 5.0, 0.2, 2.0, 2.9], 0.368, 2.273],
#  [[0.5, 3.0, 0.5, 1.7, 3.8], 0.386, 2.271],
#  [[0.5, 5.0, 0.2, 2.1, 3.0], 0.4, 2.271],
#  [[0.5, 5.0, 0.5, 2.2, 3.0], 0.421, 2.271],
#  [[0.5, 3.0, 0.5, 2.5, 4.0], 0.357, 2.27],
#  [[0.5, 5.0, 0.3, 2.7, 3.9], 0.496, 2.269],
#  [[0.5, 3.0, 0.3, 2.9, 2.9], 0.222, 2.269],
#  [[0.5, 3.0, 0.5, 2.3, 2.8], 0.34, 2.269],
#  [[0.5, 5.0, 0.4, 2.6, 2.0], 0.297, 2.269],
#  [[0.5, 5.0, 0.3, 1.6, 2.1], 0.296, 2.269],
#  [[0.5, 5.0, 0.5, 2.1, 1.6], 0.518, 2.268],
#  [[0.5, 5.0, 0.2, 2.4, 2.8], 0.306, 2.268],
#  [[0.5, 5.0, 0.3, 2.6, 2.8], 0.306, 2.268],
#  [[0.5, 5.0, 0.5, 1.9, 2.9], 0.429, 2.267],
#  [[0.5, 5.0, 0.5, 2.9, 2.9], 0.351, 2.267],
#  [[0.5, 3.0, 0.4, 1.7, 2.0], 0.301, 2.266],
#  [[0.5, 5.0, 0.2, 2.0, 3.0], 0.339, 2.265],
#  [[0.5, 3.0, 0.5, 2.8, 2.0], 0.272, 2.265],
#  [[0.5, 3.0, 0.5, 2.2, 3.6], 0.371, 2.264],
#  [[0.5, 3.0, 0.5, 2.2, 4.8], 0.371, 2.264],
#  [[0.5, 3.0, 0.5, 1.6, 2.9], 0.358, 2.264],
#  [[0.5, 5.0, 0.2, 2.7, 2.9], 0.297, 2.264],
#  [[0.5, 3.0, 0.5, 1.8, 2.1], 0.31, 2.264],
#  [[0.5, 5.0, 0.5, 2.6, 2.8], 0.35, 2.263],
#  [[0.5, 5.0, 0.4, 2.2, 2.0], 0.339, 2.263],
#  [[0.5, 3.0, 0.4, 1.7, 4.1], 0.357, 2.262],
#  [[0.5, 3.0, 0.3, 1.6, 2.0], 0.291, 2.262],
#  [[0.5, 3.0, 0.4, 1.8, 2.1], 0.303, 2.261],
#  [[0.5, 3.0, 0.5, 2.0, 2.1], 0.303, 2.261],
#  [[0.5, 5.0, 0.4, 2.3, 2.1], 0.272, 2.26]]

# %% [markdown]
# ## Min based overall

# %%
pprint(list(sorted(ans, key=lambda x:-x[-2]))[:30])
# Out:
# [[[0.5, 5.0, 0.1, 1.5, 2.3], 0.993, 2.209],
#  [[0.5, 5.0, 0.1, 2.4, 4.7], 0.962, 2.15],
#  [[0.5, 3.0, 0.1, 1.5, 2.4], 0.962, 2.071],
#  [[0.5, 5.0, 0.1, 1.8, 3.9], 0.962, 2.221],
#  [[0.5, 3.0, 0.1, 1.5, 4.1], 0.926, 2.182],
#  [[0.5, 3.0, 0.1, 1.5, 3.6], 0.926, 2.157],
#  [[0.5, 5.0, 0.1, 1.9, 4.1], 0.926, 2.176],
#  [[0.5, 5.0, 0.1, 2.4, 2.7], 0.924, 2.063],
#  [[0.5, 5.0, 0.1, 2.2, 3.8], 0.924, 2.08],
#  [[0.5, 3.0, 0.1, 1.5, 3.8], 0.896, 1.871],
#  [[0.5, 5.0, 0.1, 2.1, 4.7], 0.893, 1.959],
#  [[0.5, 5.0, 0.1, 2.5, 4.9], 0.893, 2.188],
#  [[0.5, 5.0, 0.1, 2.0, 3.3], 0.893, 2.126],
#  [[0.5, 5.0, 0.1, 2.1, 3.4], 0.893, 2.061],
#  [[0.5, 3.0, 0.1, 1.5, 4.5], 0.893, 1.962],
#  [[0.5, 3.0, 0.1, 1.7, 3.9], 0.893, 2.016],
#  [[0.5, 5.0, 0.1, 1.5, 2.2], 0.893, 1.959],
#  [[0.5, 3.0, 0.1, 2.4, 4.2], 0.874, 1.938],
#  [[0.5, 5.0, 0.1, 1.7, 3.8], 0.869, 2.166],
#  [[0.5, 3.0, 0.1, 2.0, 4.1], 0.862, 2.091],
#  [[0.5, 5.0, 0.1, 2.2, 4.5], 0.862, 2.094],
#  [[0.5, 3.0, 0.1, 1.5, 3.9], 0.862, 2.093],
#  [[0.5, 3.0, 0.1, 1.5, 2.3], 0.862, 2.086],
#  [[0.5, 3.0, 0.1, 1.6, 4.3], 0.857, 2.058],
#  [[0.5, 3.0, 0.1, 1.7, 4.1], 0.857, 2.277],
#  [[0.5, 3.0, 0.1, 2.0, 2.6], 0.847, 1.877],
#  [[0.5, 3.0, 0.1, 1.7, 4.8], 0.844, 1.739],
#  [[0.5, 5.0, 0.1, 1.8, 4.4], 0.844, 1.878],
#  [[0.5, 3.0, 0.1, 1.8, 2.3], 0.835, 1.914],
#  [[0.5, 3.0, 0.1, 1.5, 1.7], 0.833, 1.755]]
