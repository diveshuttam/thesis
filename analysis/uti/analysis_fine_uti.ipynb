# %% [markdown]
# # Analysis Fine

# %%
import csv
from pprint import pprint

# %%
momon1 = list(sorted(list(csv.reader(open("./results/fine_momon1.tsv"), delimiter='\t'))))
cemon1 = list(sorted(list(csv.reader(open("./results/fine_cemon1.tsv"), delimiter='\t'))))
momon3 = list(sorted(list(csv.reader(open("./results/fine_momon3.tsv"), delimiter='\t'))))
cemon3 = list(sorted(list(csv.reader(open("./results/fine_cemon3.tsv"), delimiter='\t'))))
momon4 = list(sorted(list(csv.reader(open("./results/fine_momon4.tsv"), delimiter='\t'))))
cemon4 = list(sorted(list(csv.reader(open("./results/fine_cemon4.tsv"), delimiter='\t'))))

# %%
print(len(momon1))
print(len(cemon1))
print(len(momon3))
print(len(cemon3))
print(len(momon4))
print(len(cemon4))
# Out:
# 3360
# 3360
# 3360
# 3360
# 3360
# 3360

# %% [markdown]
# # CeMon

# %%
ans=[]
for m1,c1,m3,c3,m4,c4 in zip(momon1,cemon1,momon3,cemon3,momon4,cemon4):
    # par = set(list(map(tuple,[m1[1:6],c1[1:6],m3[1:6],c3[1:6],m4[1:6],c4[1:6]])))
    # print(par, len(par))
    # assert(len(par)==1)
    m1=c1
    m3=c3
    m4=c4
    mi = min(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))
    avg = sum(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))/6
    ans.append([m1[1:6], mi, avg])

# %% [markdown]
# ## Avg based cemon

# %%
pprint(list(sorted(ans, key=lambda x:-x[-1]))[:30])
# Out:
# [[['0.5', '3', '0.4', '3.2', '3.9'], 0.8122615143, 1.1262823971],
#  [['0.5', '3', '0.2', '3.2', '3.9'], 0.7892254628, 1.1081121959333335],
#  [['0.5', '3', '0.4', '2', '2.6'], 0.8327571784, 1.0881356778],
#  [['0.5', '3', '0.1', '2.7', '3.7'], 0.6624349582, 1.0863408197333335],
#  [['0.5', '3', '0.4', '2.8', '3.8'], 0.9468355867, 1.0749809442999998],
#  [['0.5', '3', '0.3', '2.6', '3.8'], 0.7462532884, 1.0688230091333335],
#  [['0.5', '3', '0.3', '2', '2.6'], 0.7809843586, 1.0683774748666668],
#  [['0.5', '3', '0.4', '2', '3.8'], 0.9422062111, 1.0639425510333334],
#  [['0.5', '3', '0.2', '2.5', '4.4'], 0.9328948441, 1.0606683527],
#  [['0.5', '3', '0.1', '2.5', '3'], 0.8057322535, 1.0582318425],
#  [['0.5', '3', '0.3', '2', '3.8'], 0.9422062111, 1.0554274073666667],
#  [['0.5', '3', '0.2', '3', '3.8'], 0.8413562196, 1.0536307145333332],
#  [['0.5', '3', '0.4', '2.4', '3.7'], 0.7717784681, 1.0469874353666666],
#  [['0.5', '3', '0.2', '2.4', '3.8'], 0.8467753887, 1.0447935725666668],
# ...

# %% [markdown]
# ## Min based cemon

# %%
pprint(list(sorted(ans, key= lambda x:-x[-2]))[:60])
# Out:
# [[['0.5', '3', '0.4', '2.8', '3.8'], 0.9468355867, 1.0749809442999998],
#  [['0.5', '3', '0.2', '2', '3.3'], 0.9422575214, 1.0424145008],
#  [['0.5', '3', '0.3', '2', '3.8'], 0.9422062111, 1.0554274073666667],
#  [['0.5', '3', '0.4', '2', '3.8'], 0.9422062111, 1.0639425510333334],
#  [['0.5', '3', '0.3', '2.8', '4.3'], 0.9384507471, 1.0135500953666667],
#  [['0.5', '3', '0.2', '2.5', '4.4'], 0.9328948441, 1.0606683527],
#  [['0.5', '3', '0.2', '2', '3.8'], 0.9258432234, 1.0415127341333335],
#  [['0.5', '3', '0.2', '3.3', '3.9'], 0.9175985058, 1.0141352516],
#  [['0.5', '3', '0.2', '2.5', '4'], 0.9139051134, 1.0189035198],
#  [['0.5', '3', '0.2', '2.7', '3.4'], 0.9132915205, 0.9762951153666665],
#  [['0.5', '3', '0.5', '2.8', '3.8'], 0.9096112447, 1.0401807369666665],
#  [['0.5', '3', '0.2', '2.9', '3.9'], 0.8957585272, 0.9576304525000001],
#  [['0.5', '3', '0.2', '2.5', '4.3'], 0.895374457, 0.9988555405666667],
# ...

# %% [markdown]
# # Momon

# %%
ans=[]
for m1,c1,m3,c3,m4,c4 in zip(momon1,cemon1,momon3,cemon3,momon4,cemon4):
    # par = set(list(map(tuple,[m1[1:6],c1[1:6],m3[1:6],c3[1:6],m4[1:6],c4[1:6]])))
    # print(par, len(par))
    # assert(len(par)==1)
    c1=m1
    c3=m3
    c4=m4
    mi = min(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))
    avg = sum(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))/6
    ans.append([m1[1:6], mi, avg])

# %% [markdown]
# ## Avg based momon

# %%
pprint(list(sorted(ans, key=lambda x:-x[-1]))[:30])
# Out:
# [[['0.5', '5', '0.5', '3.4', '4.3'], 1.013993925, 1.144278244],
#  [['0.5', '3', '0.4', '3.2', '3.9'], 0.9695530548, 1.1385938286000001],
#  [['0.5', '5', '0.5', '2.1', '3.4'], 1.023496916, 1.1331475216666667],
#  [['0.5', '5', '0.2', '2.7', '3.7'], 0.8836829099, 1.1187040913],
#  [['0.5', '3', '0.2', '3.2', '3.9'], 0.9420561541, 1.115133095366667],
#  [['0.5', '5', '0.5', '2.9', '4.2'], 0.8391209383, 1.1028958661],
#  [['0.5', '3', '0.4', '2', '2.6'], 0.994017631, 1.1016372636666667],
#  [['0.5', '5', '0.3', '2.6', '3.8'], 1.035113879, 1.1015172033333334],
#  [['0.5', '5', '0.4', '2', '2.6'], 0.9852699678, 1.0987213759333334],
#  [['0.5', '3', '0.4', '2', '3.8'], 0.882017307, 1.0933480016666668],
#  [['0.5', '5', '0.4', '2', '3.3'], 0.9201617941, 1.0915719210333334],
#  [['0.5', '5', '0.5', '2', '4.3'], 0.9737399436, 1.0913850088666668],
#  [['0.5', '3', '0.4', '2.8', '3.8'], 1.026779069, 1.0900876396666666],
#  [['0.5', '3', '0.2', '2.5', '4.4'], 0.8961491857, 1.0885552972333334],
# ...

# %% [markdown]
# ## Min based momon

# %%
pprint(list(sorted(ans, key=lambda x:-x[-2]))[:30])
# Out:
# [[['0.5', '5', '0.3', '2.6', '3.8'], 1.035113879, 1.1015172033333334],
#  [['0.5', '3', '0.4', '2.8', '3.8'], 1.026779069, 1.0900876396666666],
#  [['0.5', '3', '0.5', '2.8', '3.8'], 1.026779069, 1.0558779193333334],
#  [['0.5', '5', '0.5', '2.1', '3.4'], 1.023496916, 1.1331475216666667],
#  [['0.5', '5', '0.5', '3.4', '4.3'], 1.013993925, 1.144278244],
#  [['0.5', '5', '0.4', '2.1', '3.7'], 1.011608084, 1.016093181],
#  [['0.5', '3', '0.2', '2.4', '3.8'], 1.010750418, 1.0574506426666666],
#  [['0.5', '5', '0.4', '3.1', '4.1'], 1.005900519, 1.03211755],
#  [['0.5', '5', '0.1', '2.8', '3'], 1.000138379, 1.0545868453333334],
#  [['0.5', '5', '0.4', '2.8', '3.8'], 0.9997000469, 1.0104457743],
#  [['0.5', '5', '0.5', '2.8', '3.8'], 0.9997000469, 1.0104457743],
#  [['0.5', '5', '0.4', '2.2', '4.1'], 0.9957770706, 1.0276833398666667],
#  [['0.5', '3', '0.3', '2.4', '3.7'], 0.9945960397, 1.0421357459000002],
#  [['0.5', '3', '0.4', '2', '2.6'], 0.994017631, 1.1016372636666667],
# ...

# %% [markdown]
# # Overall

# %%
ans=[]
for m1,c1,m3,c3,m4,c4 in zip(momon1,cemon1,momon3,cemon3,momon4,cemon4):
    # par = set(list(map(tuple,[m1[1:6],c1[1:6],m3[1:6],c3[1:6],m4[1:6],c4[1:6]])))
    # print(par, len(par))
    # assert(len(par)==1)
    mi = min(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))
    avg = sum(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))/6
    ans.append([m1[1:6], mi, avg])

# %% [markdown]
# ## Avg based overall

# %%
pprint(list(sorted(ans, key=lambda x:-x[-1]))[:30])
# Out:
# [[['0.5', '3', '0.4', '3.2', '3.9'], 0.8122615143, 1.1324381128499998],
#  [['0.5', '3', '0.2', '3.2', '3.9'], 0.7892254628, 1.11162264565],
#  [['0.5', '3', '0.4', '2', '2.6'], 0.8327571784, 1.0948864707333335],
#  [['0.5', '3', '0.4', '2.8', '3.8'], 0.9468355867, 1.0825342919833332],
#  [['0.5', '3', '0.1', '2.7', '3.7'], 0.6624349582, 1.0816443499166668],
#  [['0.5', '3', '0.4', '2', '3.8'], 0.882017307, 1.07864527635],
#  [['0.5', '3', '0.2', '2.5', '4.4'], 0.8961491857, 1.0746118249666667],
#  [['0.5', '3', '0.3', '2', '2.6'], 0.7809843586, 1.0736244650333333],
#  [['0.5', '3', '0.3', '2.6', '3.8'], 0.7462532884, 1.07006624685],
#  [['0.5', '3', '0.3', '2', '3.8'], 0.882017307, 1.06998541985],
#  [['0.5', '3', '0.2', '3', '3.8'], 0.8413562196, 1.0634054838499998],
#  [['0.5', '3', '0.1', '2.5', '3'], 0.8057322535, 1.0614895359],
#  [['0.5', '3', '0.2', '2', '3.8'], 0.882017307, 1.0553988590666668],
#  [['0.5', '3', '0.2', '2.7', '3.5'], 0.8513142863, 1.0546961704833333],
# ...

# %% [markdown]
# ## Min based overall

# %%
pprint(list(sorted(ans, key=lambda x:-x[-2]))[:30])
# Out:
# [[['0.5', '3', '0.4', '2.8', '3.8'], 0.9468355867, 1.0825342919833332],
#  [['0.5', '3', '0.2', '2', '3.3'], 0.9422575214, 1.0534589446],
#  [['0.5', '3', '0.3', '2.8', '4.3'], 0.9384507471, 1.0254169808833333],
#  [['0.5', '3', '0.2', '3.3', '3.9'], 0.9175985058, 1.0251430744333334],
#  [['0.5', '3', '0.2', '2.5', '4'], 0.9139051134, 1.0299489751666666],
#  [['0.5', '3', '0.2', '2.7', '3.4'], 0.9132915205, 0.9873982150833333],
#  [['0.5', '3', '0.5', '2.8', '3.8'], 0.9096112447, 1.04802932815],
#  [['0.5', '3', '0.2', '2.5', '4.4'], 0.8961491857, 1.0746118249666667],
#  [['0.5', '3', '0.2', '2.9', '3.9'], 0.8957585272, 0.9681249231500001],
#  [['0.5', '3', '0.2', '2.3', '3.9'], 0.885478724, 0.9753920461333334],
#  [['0.5', '3', '0.2', '2.2', '2.6'], 0.883811181, 1.0247131119333333],
#  [['0.5', '3', '0.2', '2', '3.8'], 0.882017307, 1.0553988590666668],
#  [['0.5', '3', '0.3', '2', '3.8'], 0.882017307, 1.06998541985],
#  [['0.5', '3', '0.4', '2', '3.8'], 0.882017307, 1.07864527635],
# ...
