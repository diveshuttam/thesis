# %% [markdown]
# # Analysis Fine1

# %%
import csv
from pprint import pprint

# %%
folder = "./output/momon_data/uti_w_tratio_fine1_results"
momon1 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_momon_nrmse_with_param_momon_1-tcp.csv")))))
cemon1 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_cemon_nrmse_with_param_momon_1-tcp.csv")))))
momon3 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_momon_nrmse_with_param_momon3-tcp.csv")))))
cemon3 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_cemon_nrmse_with_param_momon3-tcp.csv")))))
momon4 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_momon_nrmse_with_param_momon4-tcp.csv")))))
cemon4 = list(sorted(list(csv.reader(open(f"{folder}/error_curvature_cemon_nrmse_with_param_momon4-tcp.csv")))))

# %%
print(len(momon1))
print(len(cemon1))
print(len(momon3))
print(len(cemon3))
print(len(momon4))
print(len(cemon4))
# Out:
# 1210
# 1210
# 1210
# 1210
# 1210
# 1210

# %% [markdown]
# # CeMon

# %%
ans=[]
def convert(m1_):
    m1 = [m1_[1]]+list(map(lambda x:round(float(x),3),[m1_[18],m1_[20],m1_[22],m1_[24],m1_[26],m1_[4],m1_[6],m1_[11],m1_[13]]))
    m1.extend([m1[-4]*m1[-2],m1[-3]*m1[-1]])
    m1.append(round(m1[-1]/m1[-2],3))
    return m1
    
for m1_,c1_,m3_,c3_,m4_,c4_ in zip(momon1,cemon1,momon3,cemon3,momon4,cemon4):
    # par = set(list(map(tuple,[m1[1:6],c1[1:6],m3[1:6],c3[1:6],m4[1:6],c4[1:6]])))
    # print(par, len(par))
    # assert(len(par)==1)
    # pprint(list(enumerate(m1_)))
    # m1.append(m1[])
    m1 = convert(m1_)
    c1 = convert(c1_)
    m4 = convert(m4_)
    c4 = convert(c4_)
    m3 = convert(m3_)
    c3 = convert(c3_)
    # pprint([m1,c1,m3,c3,m4,c4])
    m1=c1
    m3=c3
    m4=c4
    mi = min(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))
    avg = round(sum(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))/6,3)
    ans.append([m1[1:6], mi, avg])

# %% [markdown]
# ## Avg based cemon

# %%
pprint(list(sorted(ans, key=lambda x:-x[-1]))[:30])
# Out:
# [[[0.5, 3.0, 0.5, 2.0, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.1, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.2, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.3, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.4, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.5, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.6, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.7, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.8, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.9, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 3.0, 1.1], 1.271, 1.734],
#  [[0.5, 5.0, 0.5, 2.0, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.1, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.2, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.3, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.4, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.5, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.6, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.7, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.8, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.9, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 3.0, 1.1], 1.163, 1.475],
#  [[0.5, 3.0, 0.2, 2.0, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.1, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.2, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.3, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.4, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.5, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.6, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.7, 1.1], 1.004, 1.416]]

# %% [markdown]
# ## Min based cemon

# %%
pprint(list(sorted(ans, key= lambda x:-x[-2]))[:60])
# Out:
# [[[0.5, 3.0, 0.5, 2.0, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.1, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.2, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.3, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.4, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.5, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.6, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.7, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.8, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 2.9, 1.1], 1.271, 1.734],
#  [[0.5, 3.0, 0.5, 3.0, 1.1], 1.271, 1.734],
#  [[0.5, 5.0, 0.5, 2.0, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.1, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.2, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.3, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.4, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.5, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.6, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.7, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.8, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 2.9, 1.1], 1.163, 1.475],
#  [[0.5, 5.0, 0.5, 3.0, 1.1], 1.163, 1.475],
#  [[0.5, 3.0, 0.1, 2.0, 1.2], 1.015, 1.241],
#  [[0.5, 3.0, 0.1, 2.1, 1.2], 1.015, 1.241],
#  [[0.5, 3.0, 0.1, 2.2, 1.2], 1.015, 1.241],
#  [[0.5, 3.0, 0.1, 2.3, 1.2], 1.015, 1.241],
#  [[0.5, 3.0, 0.1, 2.0, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 2.1, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 2.2, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 2.3, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 2.4, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 2.5, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 2.6, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 2.7, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 2.8, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 2.9, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 3.0, 1.3], 1.013, 1.206],
#  [[0.5, 3.0, 0.1, 2.4, 1.2], 1.005, 1.167],
#  [[0.5, 3.0, 0.1, 2.5, 1.2], 1.005, 1.167],
#  [[0.5, 3.0, 0.1, 2.6, 1.2], 1.005, 1.167],
#  [[0.5, 3.0, 0.1, 2.7, 1.2], 1.005, 1.167],
#  [[0.5, 3.0, 0.1, 2.8, 1.2], 1.005, 1.167],
#  [[0.5, 3.0, 0.1, 2.9, 1.2], 1.005, 1.167],
#  [[0.5, 3.0, 0.1, 3.0, 1.2], 1.005, 1.167],
#  [[0.5, 3.0, 0.2, 2.0, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.1, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.2, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.3, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.4, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.5, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.6, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.7, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.8, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 2.9, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.2, 3.0, 1.1], 1.004, 1.416],
#  [[0.5, 3.0, 0.3, 2.0, 1.3], 0.988, 1.29],
#  [[0.5, 3.0, 0.3, 2.1, 1.3], 0.988, 1.29],
#  [[0.5, 3.0, 0.3, 2.2, 1.3], 0.988, 1.21],
#  [[0.5, 3.0, 0.3, 2.3, 1.3], 0.988, 1.21],
#  [[0.5, 3.0, 0.3, 2.4, 1.3], 0.988, 1.21]]

# %% [markdown]
# # Momon

# %%
ans=[]
def convert(m1_):
    m1 = [m1_[1]]+list(map(lambda x:round(float(x),3),[m1_[18],m1_[20],m1_[22],m1_[24],m1_[26],m1_[4],m1_[6],m1_[11],m1_[13]]))
    m1.extend([m1[-4]*m1[-2],m1[-3]*m1[-1]])
    m1.append(round(m1[-1]/m1[-2],3))
    return m1
    
for m1_,c1_,m3_,c3_,m4_,c4_ in zip(momon1,cemon1,momon3,cemon3,momon4,cemon4):
    # par = set(list(map(tuple,[m1[1:6],c1[1:6],m3[1:6],c3[1:6],m4[1:6],c4[1:6]])))
    # print(par, len(par))
    # assert(len(par)==1)
    # pprint(list(enumerate(m1_)))
    # m1.append(m1[])
    m1 = convert(m1_)
    c1 = convert(c1_)
    m4 = convert(m4_)
    c4 = convert(c4_)
    m3 = convert(m3_)
    c3 = convert(c3_)
    # pprint([m1,c1,m3,c3,m4,c4])
    c1=m1
    c3=m3
    c4=m4
    mi = min(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))
    avg = round(sum(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))/6,3)
    ans.append([m1[1:6], mi, avg])

# %% [markdown]
# ## Avg based momon

# %%
pprint(list(sorted(ans, key=lambda x:-x[-1]))[:30])
# Out:
# [[[0.5, 3.0, 0.5, 2.0, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.1, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.2, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.3, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.4, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.5, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.6, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.7, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.8, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.9, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 3.0, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.0, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.1, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.2, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.3, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.4, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.5, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.6, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.7, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.8, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.9, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 3.0, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.2, 2.0, 1.1], 1.092, 1.519],
#  [[0.5, 3.0, 0.2, 2.1, 1.1], 1.092, 1.519],
#  [[0.5, 3.0, 0.2, 2.2, 1.1], 1.092, 1.519],
#  [[0.5, 3.0, 0.2, 2.3, 1.1], 1.092, 1.519],
#  [[0.5, 3.0, 0.2, 2.4, 1.1], 1.092, 1.519],
#  [[0.5, 3.0, 0.2, 2.5, 1.1], 1.092, 1.519],
#  [[0.5, 3.0, 0.2, 2.6, 1.1], 1.092, 1.519],
#  [[0.5, 3.0, 0.2, 2.7, 1.1], 1.092, 1.519]]

# %% [markdown]
# ## Min based momon

# %%
pprint(list(sorted(ans, key=lambda x:-x[-2]))[:30])
# Out:
# [[[0.5, 3.0, 0.5, 2.0, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.1, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.2, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.3, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.4, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.5, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.6, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.7, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.8, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 2.9, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.5, 3.0, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.0, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.1, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.2, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.3, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.4, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.5, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.6, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.7, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.8, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 2.9, 1.1], 1.383, 1.823],
#  [[0.5, 5.0, 0.5, 3.0, 1.1], 1.383, 1.823],
#  [[0.5, 3.0, 0.1, 2.0, 1.2], 1.105, 1.23],
#  [[0.5, 3.0, 0.1, 2.1, 1.2], 1.105, 1.23],
#  [[0.5, 3.0, 0.1, 2.2, 1.2], 1.105, 1.242],
#  [[0.5, 3.0, 0.1, 2.3, 1.2], 1.105, 1.242],
#  [[0.5, 3.0, 0.1, 2.4, 1.2], 1.105, 1.219],
#  [[0.5, 3.0, 0.1, 2.5, 1.2], 1.105, 1.219],
#  [[0.5, 3.0, 0.1, 2.6, 1.2], 1.105, 1.219],
#  [[0.5, 3.0, 0.1, 2.7, 1.2], 1.105, 1.219]]

# %% [markdown]
# # Overall

# %%
ans=[]
def convert(m1_):
    m1 = [m1_[1]]+list(map(lambda x:round(float(x),3),[m1_[18],m1_[20],m1_[22],m1_[24],m1_[26],m1_[4],m1_[6],m1_[11],m1_[13]]))
    m1.extend([m1[-4]*m1[-2],m1[-3]*m1[-1]])
    m1.append(round(m1[-1]/m1[-2],3))
    return m1
    
for m1_,c1_,m3_,c3_,m4_,c4_ in zip(momon1,cemon1,momon3,cemon3,momon4,cemon4):
    # par = set(list(map(tuple,[m1[1:6],c1[1:6],m3[1:6],c3[1:6],m4[1:6],c4[1:6]])))
    # print(par, len(par))
    # assert(len(par)==1)
    # pprint(list(enumerate(m1_)))
    # m1.append(m1[])
    m1 = convert(m1_)
    c1 = convert(c1_)
    m4 = convert(m4_)
    c4 = convert(c4_)
    m3 = convert(m3_)
    c3 = convert(c3_)
    # pprint([m1,c1,m3,c3,m4,c4])
    mi = min(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))
    avg = round(sum(map(float,[m1[-1],c1[-1],m3[-1],c3[-1],m4[-1],c4[-1]]))/6,3)
    ans.append([m1[1:6], mi, avg])

# %% [markdown]
# ## Avg based overall

# %%
pprint(list(sorted(ans, key=lambda x:-x[-1]))[:400])
# Out:
# [[[0.5, 5.0, 0.5, 2.0, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.1, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.2, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.3, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.4, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.5, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.6, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.7, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.8, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.9, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 3.0, 1.1], 1.271, 1.778],
#  [[0.5, 3.0, 0.5, 2.0, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.1, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.2, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.3, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.4, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.5, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.6, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.7, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.8, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.9, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 3.0, 1.1], 1.163, 1.649],
#  [[0.5, 5.0, 0.2, 2.0, 1.1], 1.004, 1.467],
#  [[0.5, 5.0, 0.2, 2.1, 1.1], 1.004, 1.467],
#  [[0.5, 5.0, 0.2, 2.2, 1.1], 1.004, 1.467],
#  [[0.5, 5.0, 0.2, 2.3, 1.1], 1.004, 1.467],
#  [[0.5, 5.0, 0.2, 2.4, 1.1], 1.004, 1.467],
#  [[0.5, 5.0, 0.2, 2.5, 1.1], 1.004, 1.467],
#  [[0.5, 5.0, 0.2, 2.6, 1.1], 1.004, 1.467],
#  [[0.5, 5.0, 0.2, 2.7, 1.1], 1.004, 1.467],
#  [[0.5, 5.0, 0.2, 2.8, 1.1], 1.004, 1.467],
#  [[0.5, 5.0, 0.2, 2.9, 1.1], 1.004, 1.467],
#  [[0.5, 5.0, 0.2, 3.0, 1.1], 1.004, 1.467],
#  [[0.5, 3.0, 0.2, 2.0, 1.1], 0.835, 1.388],
#  [[0.5, 3.0, 0.2, 2.1, 1.1], 0.835, 1.388],
#  [[0.5, 3.0, 0.2, 2.2, 1.1], 0.835, 1.388],
#  [[0.5, 3.0, 0.2, 2.3, 1.1], 0.835, 1.388],
#  [[0.5, 3.0, 0.2, 2.4, 1.1], 0.835, 1.388],
#  [[0.5, 3.0, 0.2, 2.5, 1.1], 0.835, 1.388],
#  [[0.5, 3.0, 0.2, 2.6, 1.1], 0.835, 1.388],
#  [[0.5, 3.0, 0.2, 2.7, 1.1], 0.835, 1.388],
#  [[0.5, 3.0, 0.2, 2.8, 1.1], 0.835, 1.388],
#  [[0.5, 3.0, 0.2, 2.9, 1.1], 0.835, 1.388],
#  [[0.5, 3.0, 0.2, 3.0, 1.1], 0.835, 1.388],
#  [[0.5, 5.0, 0.3, 2.0, 1.3], 0.988, 1.277],
#  [[0.5, 5.0, 0.3, 2.1, 1.3], 0.988, 1.277],
#  [[0.5, 5.0, 0.3, 2.2, 1.3], 0.988, 1.238],
#  [[0.5, 5.0, 0.3, 2.3, 1.3], 0.988, 1.238],
#  [[0.5, 5.0, 0.3, 2.4, 1.3], 0.988, 1.238],
#  [[0.5, 5.0, 0.3, 2.5, 1.3], 0.988, 1.238],
#  [[0.5, 5.0, 0.3, 2.6, 1.3], 0.988, 1.238],
#  [[0.5, 5.0, 0.3, 2.7, 1.3], 0.988, 1.238],
#  [[0.5, 5.0, 0.3, 2.8, 1.3], 0.988, 1.238],
#  [[0.5, 5.0, 0.3, 2.9, 1.3], 0.988, 1.238],
#  [[0.5, 5.0, 0.3, 3.0, 1.3], 0.988, 1.238],
#  [[0.5, 5.0, 0.2, 2.0, 1.2], 0.979, 1.237],
#  [[0.5, 5.0, 0.2, 2.1, 1.2], 0.979, 1.237],
#  [[0.5, 5.0, 0.1, 2.0, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.1, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.2, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.3, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.4, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.5, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.6, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.7, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.8, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.9, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 3.0, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.0, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 2.1, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 2.2, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 2.3, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 2.4, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 2.5, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 2.6, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 2.7, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 2.8, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 2.9, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 3.0, 1.1], 0.987, 1.23],
#  [[0.5, 5.0, 0.1, 2.0, 1.2], 1.015, 1.23],
#  [[0.5, 5.0, 0.1, 2.1, 1.2], 1.015, 1.23],
#  [[0.5, 5.0, 0.1, 2.2, 1.2], 1.015, 1.23],
#  [[0.5, 5.0, 0.1, 2.3, 1.2], 1.015, 1.23],
#  [[0.5, 5.0, 0.5, 2.3, 1.2], 0.948, 1.217],
#  [[0.5, 5.0, 0.5, 2.4, 1.2], 0.948, 1.217],
#  [[0.5, 5.0, 0.5, 2.5, 1.2], 0.948, 1.217],
#  [[0.5, 5.0, 0.5, 2.6, 1.2], 0.948, 1.217],
#  [[0.5, 5.0, 0.5, 2.7, 1.2], 0.948, 1.217],
#  [[0.5, 5.0, 0.5, 2.8, 1.2], 0.948, 1.217],
#  [[0.5, 5.0, 0.5, 2.9, 1.2], 0.948, 1.217],
#  [[0.5, 5.0, 0.5, 3.0, 1.2], 0.948, 1.217],
#  [[0.5, 5.0, 0.5, 2.0, 1.3], 0.948, 1.213],
#  [[0.5, 5.0, 0.5, 2.1, 1.3], 0.948, 1.213],
#  [[0.5, 5.0, 0.5, 2.2, 1.3], 0.948, 1.213],
#  [[0.5, 5.0, 0.5, 2.3, 1.3], 0.948, 1.213],
#  [[0.5, 5.0, 0.4, 2.3, 1.2], 0.948, 1.205],
#  [[0.5, 5.0, 0.4, 2.4, 1.2], 0.948, 1.205],
#  [[0.5, 5.0, 0.4, 2.5, 1.2], 0.948, 1.205],
#  [[0.5, 5.0, 0.4, 2.6, 1.2], 0.948, 1.205],
#  [[0.5, 5.0, 0.4, 2.7, 1.2], 0.948, 1.205],
#  [[0.5, 5.0, 0.4, 2.8, 1.2], 0.948, 1.205],
#  [[0.5, 5.0, 0.4, 2.9, 1.2], 0.948, 1.205],
#  [[0.5, 5.0, 0.4, 3.0, 1.2], 0.948, 1.205],
#  [[0.5, 5.0, 0.2, 2.2, 1.2], 0.979, 1.199],
#  [[0.5, 5.0, 0.2, 2.3, 1.2], 0.979, 1.199],
#  [[0.5, 5.0, 0.2, 2.4, 1.2], 0.979, 1.199],
#  [[0.5, 5.0, 0.2, 2.5, 1.2], 0.979, 1.199],
#  [[0.5, 5.0, 0.2, 2.6, 1.2], 0.979, 1.199],
#  [[0.5, 5.0, 0.2, 2.7, 1.2], 0.979, 1.199],
#  [[0.5, 5.0, 0.2, 2.8, 1.2], 0.979, 1.199],
#  [[0.5, 5.0, 0.2, 2.9, 1.2], 0.979, 1.199],
#  [[0.5, 5.0, 0.2, 3.0, 1.2], 0.979, 1.199],
#  [[0.5, 5.0, 0.1, 2.4, 1.2], 1.005, 1.193],
#  [[0.5, 5.0, 0.1, 2.5, 1.2], 1.005, 1.193],
#  [[0.5, 5.0, 0.1, 2.6, 1.2], 1.005, 1.193],
#  [[0.5, 5.0, 0.1, 2.7, 1.2], 1.005, 1.193],
#  [[0.5, 5.0, 0.1, 2.8, 1.2], 1.005, 1.193],
#  [[0.5, 5.0, 0.1, 2.9, 1.2], 1.005, 1.193],
#  [[0.5, 5.0, 0.1, 3.0, 1.2], 1.005, 1.193],
#  [[0.5, 5.0, 0.4, 2.0, 1.2], 0.948, 1.178],
#  [[0.5, 5.0, 0.4, 2.1, 1.2], 0.948, 1.178],
#  [[0.5, 5.0, 0.4, 2.2, 1.2], 0.948, 1.178],
#  [[0.5, 5.0, 0.5, 2.4, 1.3], 0.948, 1.176],
#  [[0.5, 5.0, 0.5, 2.5, 1.3], 0.948, 1.176],
#  [[0.5, 5.0, 0.5, 2.6, 1.3], 0.948, 1.176],
#  [[0.5, 5.0, 0.5, 2.7, 1.3], 0.948, 1.176],
#  [[0.5, 5.0, 0.5, 2.8, 1.3], 0.948, 1.176],
#  [[0.5, 5.0, 0.5, 2.9, 1.3], 0.948, 1.176],
#  [[0.5, 5.0, 0.5, 3.0, 1.3], 0.948, 1.176],
#  [[0.5, 5.0, 0.4, 2.0, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.4, 2.1, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.4, 2.2, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.4, 2.3, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.4, 2.4, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.4, 2.5, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.4, 2.6, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.4, 2.7, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.4, 2.8, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.4, 2.9, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.4, 3.0, 1.3], 0.911, 1.17],
#  [[0.5, 5.0, 0.5, 2.0, 1.2], 0.948, 1.162],
#  [[0.5, 5.0, 0.5, 2.1, 1.2], 0.948, 1.162],
#  [[0.5, 5.0, 0.5, 2.2, 1.2], 0.948, 1.162],
#  [[0.5, 5.0, 0.3, 2.0, 1.2], 0.834, 1.153],
#  [[0.5, 5.0, 0.3, 2.1, 1.2], 0.834, 1.153],
#  [[0.5, 5.0, 0.3, 2.2, 1.2], 0.834, 1.153],
#  [[0.5, 5.0, 0.3, 2.3, 1.2], 0.834, 1.153],
#  [[0.5, 3.0, 0.3, 2.0, 1.3], 0.817, 1.141],
#  [[0.5, 3.0, 0.3, 2.2, 1.3], 0.817, 1.141],
#  [[0.5, 3.0, 0.3, 2.3, 1.3], 0.817, 1.141],
#  [[0.5, 3.0, 0.3, 2.4, 1.3], 0.817, 1.141],
#  [[0.5, 3.0, 0.3, 2.5, 1.3], 0.817, 1.141],
#  [[0.5, 3.0, 0.3, 2.6, 1.3], 0.817, 1.141],
#  [[0.5, 3.0, 0.3, 2.7, 1.3], 0.817, 1.141],
#  [[0.5, 3.0, 0.3, 2.8, 1.3], 0.817, 1.141],
#  [[0.5, 3.0, 0.3, 2.9, 1.3], 0.817, 1.141],
#  [[0.5, 3.0, 0.3, 3.0, 1.3], 0.817, 1.141],
#  [[0.5, 5.0, 0.4, 2.5, 1.1], 0.911, 1.14],
#  [[0.5, 3.0, 0.1, 2.0, 1.1], 0.805, 1.136],
#  [[0.5, 3.0, 0.1, 2.1, 1.1], 0.805, 1.136],
#  [[0.5, 3.0, 0.1, 2.2, 1.1], 0.805, 1.136],
#  [[0.5, 3.0, 0.1, 2.3, 1.1], 0.805, 1.136],
#  [[0.5, 3.0, 0.1, 2.4, 1.1], 0.805, 1.136],
#  [[0.5, 3.0, 0.1, 2.5, 1.1], 0.805, 1.136],
#  [[0.5, 3.0, 0.1, 2.6, 1.1], 0.805, 1.136],
#  [[0.5, 3.0, 0.1, 2.7, 1.1], 0.805, 1.136],
#  [[0.5, 3.0, 0.1, 2.8, 1.1], 0.805, 1.136],
#  [[0.5, 3.0, 0.1, 2.9, 1.1], 0.805, 1.136],
#  [[0.5, 3.0, 0.1, 3.0, 1.1], 0.805, 1.136],
#  [[0.5, 5.0, 0.4, 2.7, 1.1], 0.911, 1.136],
#  [[0.5, 3.0, 0.1, 2.0, 1.3], 0.817, 1.134],
#  [[0.5, 3.0, 0.1, 2.1, 1.3], 0.817, 1.134],
#  [[0.5, 3.0, 0.1, 2.2, 1.3], 0.817, 1.134],
#  [[0.5, 3.0, 0.1, 2.3, 1.3], 0.817, 1.134],
#  [[0.5, 3.0, 0.1, 2.4, 1.3], 0.817, 1.134],
#  [[0.5, 3.0, 0.1, 2.5, 1.3], 0.817, 1.134],
#  [[0.5, 3.0, 0.1, 2.6, 1.3], 0.817, 1.134],
#  [[0.5, 3.0, 0.1, 2.7, 1.3], 0.817, 1.134],
#  [[0.5, 3.0, 0.1, 2.8, 1.3], 0.817, 1.134],
#  [[0.5, 3.0, 0.1, 2.9, 1.3], 0.817, 1.134],
#  [[0.5, 3.0, 0.1, 3.0, 1.3], 0.817, 1.134],
#  [[0.5, 5.0, 0.5, 2.0, 1.4], 0.834, 1.13],
#  [[0.5, 5.0, 0.5, 2.1, 1.4], 0.834, 1.13],
#  [[0.5, 5.0, 0.5, 2.2, 1.4], 0.834, 1.13],
#  [[0.5, 5.0, 0.5, 2.3, 1.4], 0.834, 1.13],
#  [[0.5, 5.0, 0.4, 2.9, 1.4], 0.911, 1.13],
#  [[0.5, 5.0, 0.1, 2.5, 1.4], 0.921, 1.129],
#  [[0.5, 3.0, 0.1, 2.2, 1.2], 0.779, 1.121],
#  [[0.5, 5.0, 0.3, 2.4, 1.2], 0.834, 1.117],
#  [[0.5, 5.0, 0.3, 2.5, 1.2], 0.834, 1.117],
#  [[0.5, 5.0, 0.3, 2.6, 1.2], 0.834, 1.117],
#  [[0.5, 5.0, 0.3, 2.7, 1.2], 0.834, 1.117],
#  [[0.5, 5.0, 0.3, 2.8, 1.2], 0.834, 1.117],
#  [[0.5, 5.0, 0.3, 2.9, 1.2], 0.834, 1.117],
#  [[0.5, 5.0, 0.3, 3.0, 1.2], 0.834, 1.117],
#  [[0.5, 5.0, 0.1, 2.3, 1.4], 0.921, 1.117],
#  [[0.5, 5.0, 0.1, 2.9, 1.4], 0.921, 1.117],
#  [[0.5, 5.0, 0.4, 2.0, 1.1], 0.911, 1.113],
#  [[0.5, 5.0, 0.4, 2.1, 1.1], 0.911, 1.113],
#  [[0.5, 5.0, 0.4, 2.2, 1.1], 0.911, 1.113],
#  [[0.5, 5.0, 0.4, 2.3, 1.1], 0.911, 1.113],
#  [[0.5, 5.0, 0.4, 2.4, 1.1], 0.911, 1.113],
#  [[0.5, 5.0, 0.1, 2.7, 1.4], 0.921, 1.109],
#  [[0.5, 3.0, 0.2, 2.2, 1.2], 0.792, 1.103],
#  [[0.5, 3.0, 0.2, 2.3, 1.2], 0.792, 1.103],
#  [[0.5, 3.0, 0.2, 2.4, 1.2], 0.792, 1.103],
#  [[0.5, 3.0, 0.2, 2.5, 1.2], 0.792, 1.103],
#  [[0.5, 3.0, 0.2, 2.6, 1.2], 0.792, 1.103],
#  [[0.5, 3.0, 0.2, 2.7, 1.2], 0.792, 1.103],
#  [[0.5, 3.0, 0.2, 2.8, 1.2], 0.792, 1.103],
#  [[0.5, 3.0, 0.2, 2.9, 1.2], 0.792, 1.103],
#  [[0.5, 3.0, 0.2, 3.0, 1.2], 0.792, 1.103],
#  [[0.5, 5.0, 0.4, 2.6, 1.1], 0.911, 1.102],
#  [[0.5, 5.0, 0.2, 2.0, 1.3], 0.911, 1.102],
#  [[0.5, 5.0, 0.2, 2.1, 1.3], 0.911, 1.102],
#  [[0.5, 5.0, 0.1, 2.1, 1.4], 0.921, 1.102],
#  [[0.5, 3.0, 0.3, 2.1, 1.3], 0.817, 1.101],
#  [[0.5, 3.0, 0.1, 2.4, 1.2], 0.779, 1.099],
#  [[0.5, 3.0, 0.1, 2.5, 1.2], 0.779, 1.099],
#  [[0.5, 3.0, 0.1, 2.6, 1.2], 0.779, 1.099],
#  [[0.5, 3.0, 0.1, 2.7, 1.2], 0.779, 1.099],
#  [[0.5, 3.0, 0.1, 2.8, 1.2], 0.779, 1.099],
#  [[0.5, 3.0, 0.1, 2.9, 1.2], 0.779, 1.099],
#  [[0.5, 3.0, 0.1, 3.0, 1.2], 0.779, 1.099],
#  [[0.5, 5.0, 0.4, 2.8, 1.1], 0.911, 1.098],
#  [[0.5, 5.0, 0.4, 2.9, 1.1], 0.911, 1.097],
#  [[0.5, 5.0, 0.4, 3.0, 1.1], 0.911, 1.097],
#  [[0.5, 5.0, 0.2, 2.0, 1.4], 0.929, 1.097],
#  [[0.5, 5.0, 0.2, 2.1, 1.4], 0.929, 1.097],
#  [[0.5, 5.0, 0.2, 2.2, 1.4], 0.929, 1.097],
#  [[0.5, 5.0, 0.2, 2.3, 1.4], 0.929, 1.097],
#  [[0.5, 5.0, 0.2, 2.4, 1.4], 0.929, 1.097],
#  [[0.5, 5.0, 0.2, 2.5, 1.4], 0.929, 1.097],
#  [[0.5, 5.0, 0.5, 2.4, 1.4], 0.834, 1.094],
#  [[0.5, 5.0, 0.5, 2.5, 1.4], 0.834, 1.094],
#  [[0.5, 5.0, 0.5, 2.6, 1.4], 0.834, 1.094],
#  [[0.5, 5.0, 0.5, 2.7, 1.4], 0.834, 1.094],
#  [[0.5, 5.0, 0.5, 2.8, 1.4], 0.834, 1.094],
#  [[0.5, 5.0, 0.5, 2.9, 1.4], 0.834, 1.094],
#  [[0.5, 5.0, 0.5, 3.0, 1.4], 0.834, 1.094],
#  [[0.5, 5.0, 0.4, 3.0, 1.4], 0.911, 1.094],
#  [[0.5, 5.0, 0.1, 2.6, 1.4], 0.921, 1.091],
#  [[0.5, 3.0, 0.2, 2.0, 1.2], 0.792, 1.087],
#  [[0.5, 3.0, 0.2, 2.1, 1.2], 0.792, 1.087],
#  [[0.5, 3.0, 0.4, 2.4, 1.2], 0.782, 1.085],
#  [[0.5, 3.0, 0.4, 2.5, 1.2], 0.782, 1.085],
#  [[0.5, 3.0, 0.4, 2.6, 1.2], 0.782, 1.085],
#  [[0.5, 3.0, 0.4, 2.7, 1.2], 0.782, 1.085],
#  [[0.5, 3.0, 0.4, 2.8, 1.2], 0.782, 1.085],
#  [[0.5, 5.0, 0.1, 2.0, 1.4], 0.921, 1.084],
#  [[0.5, 3.0, 0.1, 2.3, 1.2], 0.779, 1.082],
#  [[0.5, 3.0, 0.5, 2.4, 1.3], 0.796, 1.08],
#  [[0.5, 3.0, 0.5, 2.5, 1.3], 0.796, 1.08],
#  [[0.5, 3.0, 0.5, 2.6, 1.3], 0.796, 1.08],
#  [[0.5, 3.0, 0.5, 2.7, 1.3], 0.796, 1.08],
#  [[0.5, 3.0, 0.5, 2.8, 1.3], 0.796, 1.08],
#  [[0.5, 3.0, 0.5, 2.9, 1.3], 0.796, 1.08],
#  [[0.5, 3.0, 0.5, 3.0, 1.3], 0.796, 1.08],
#  [[0.5, 5.0, 0.1, 2.4, 1.4], 0.921, 1.08],
#  [[0.5, 5.0, 0.1, 3.0, 1.4], 0.921, 1.08],
#  [[0.5, 5.0, 0.4, 2.3, 1.5], 0.929, 1.079],
#  [[0.5, 5.0, 0.4, 2.4, 1.5], 0.929, 1.079],
#  [[0.5, 5.0, 0.4, 2.5, 1.5], 0.929, 1.079],
#  [[0.5, 5.0, 0.4, 2.6, 1.5], 0.929, 1.079],
#  [[0.5, 5.0, 0.4, 2.7, 1.5], 0.929, 1.079],
#  [[0.5, 3.0, 0.4, 2.0, 1.3], 0.778, 1.078],
#  [[0.5, 3.0, 0.4, 2.1, 1.3], 0.778, 1.078],
#  [[0.5, 3.0, 0.4, 2.2, 1.3], 0.778, 1.078],
#  [[0.5, 3.0, 0.4, 2.3, 1.3], 0.778, 1.078],
#  [[0.5, 3.0, 0.4, 2.4, 1.3], 0.778, 1.078],
#  [[0.5, 3.0, 0.4, 2.5, 1.3], 0.778, 1.078],
#  [[0.5, 3.0, 0.4, 2.6, 1.3], 0.778, 1.078],
#  [[0.5, 3.0, 0.4, 2.7, 1.3], 0.778, 1.078],
#  [[0.5, 3.0, 0.3, 2.2, 1.2], 0.762, 1.075],
#  [[0.5, 5.0, 0.1, 2.8, 1.4], 0.921, 1.073],
#  [[0.5, 5.0, 0.1, 2.1, 1.0], 0.907, 1.073],
#  [[0.5, 3.0, 0.1, 2.0, 1.2], 0.779, 1.072],
#  [[0.5, 3.0, 0.1, 2.1, 1.2], 0.779, 1.072],
#  [[0.5, 5.0, 0.4, 2.0, 1.4], 0.911, 1.072],
#  [[0.5, 5.0, 0.4, 2.1, 1.4], 0.911, 1.072],
#  [[0.5, 5.0, 0.4, 2.2, 1.4], 0.911, 1.072],
#  [[0.5, 5.0, 0.4, 2.3, 1.4], 0.911, 1.072],
#  [[0.5, 5.0, 0.4, 2.4, 1.4], 0.911, 1.072],
#  [[0.5, 5.0, 0.4, 2.5, 1.4], 0.911, 1.072],
#  [[0.5, 5.0, 0.4, 2.6, 1.4], 0.911, 1.072],
#  [[0.5, 5.0, 0.4, 2.7, 1.4], 0.911, 1.072],
#  [[0.5, 5.0, 0.4, 2.8, 1.4], 0.911, 1.072],
#  [[0.5, 3.0, 0.5, 2.0, 1.2], 0.772, 1.069],
#  [[0.5, 3.0, 0.5, 2.1, 1.2], 0.772, 1.069],
#  [[0.5, 3.0, 0.5, 2.2, 1.2], 0.772, 1.069],
#  [[0.5, 5.0, 0.3, 2.9, 1.0], 0.871, 1.069],
#  [[0.5, 5.0, 0.2, 2.2, 1.3], 0.911, 1.067],
#  [[0.5, 5.0, 0.2, 2.3, 1.3], 0.911, 1.067],
#  [[0.5, 5.0, 0.2, 2.4, 1.3], 0.911, 1.067],
#  [[0.5, 5.0, 0.2, 2.5, 1.3], 0.911, 1.067],
#  [[0.5, 5.0, 0.2, 2.6, 1.3], 0.911, 1.067],
#  [[0.5, 5.0, 0.2, 2.7, 1.3], 0.911, 1.067],
#  [[0.5, 5.0, 0.2, 2.8, 1.3], 0.911, 1.067],
#  [[0.5, 5.0, 0.2, 2.9, 1.3], 0.911, 1.067],
#  [[0.5, 5.0, 0.2, 3.0, 1.3], 0.911, 1.067],
#  [[0.5, 5.0, 0.1, 2.2, 1.4], 0.921, 1.066],
#  [[0.5, 5.0, 0.3, 2.7, 1.0], 0.871, 1.065],
#  [[0.5, 5.0, 0.2, 2.6, 1.4], 0.929, 1.062],
#  [[0.5, 5.0, 0.2, 2.7, 1.4], 0.929, 1.062],
#  [[0.5, 5.0, 0.2, 2.8, 1.4], 0.929, 1.062],
#  [[0.5, 5.0, 0.2, 2.9, 1.4], 0.929, 1.062],
#  [[0.5, 5.0, 0.2, 3.0, 1.4], 0.929, 1.062],
#  [[0.5, 5.0, 0.3, 2.3, 1.0], 0.871, 1.06],
#  [[0.5, 5.0, 0.5, 2.1, 1.0], 0.902, 1.059],
#  [[0.5, 5.0, 0.4, 2.0, 1.0], 0.825, 1.056],
#  [[0.5, 5.0, 0.4, 2.1, 1.5], 0.85, 1.055],
#  [[0.5, 5.0, 0.4, 2.2, 1.5], 0.85, 1.055],
#  [[0.5, 5.0, 0.3, 2.9, 1.4], 0.876, 1.05],
#  [[0.5, 5.0, 0.3, 2.5, 1.0], 0.871, 1.049],
#  [[0.5, 5.0, 0.4, 2.6, 1.0], 0.825, 1.048],
#  [[0.5, 5.0, 0.4, 3.0, 1.0], 0.825, 1.048],
#  [[0.5, 5.0, 0.5, 2.5, 1.0], 0.902, 1.048],
#  [[0.5, 3.0, 0.5, 2.0, 1.3], 0.796, 1.047],
#  [[0.5, 3.0, 0.5, 2.1, 1.3], 0.796, 1.047],
#  [[0.5, 3.0, 0.5, 2.2, 1.3], 0.796, 1.047],
#  [[0.5, 3.0, 0.5, 2.3, 1.3], 0.796, 1.047],
#  [[0.5, 3.0, 0.4, 2.9, 1.2], 0.782, 1.047],
#  [[0.5, 3.0, 0.4, 3.0, 1.2], 0.782, 1.047],
#  [[0.5, 5.0, 0.4, 2.8, 1.5], 0.893, 1.046],
#  [[0.5, 5.0, 0.4, 2.9, 1.5], 0.893, 1.046],
#  [[0.5, 5.0, 0.4, 3.0, 1.5], 0.893, 1.046],
#  [[0.5, 5.0, 0.4, 2.0, 1.5], 0.893, 1.046],
#  [[0.5, 5.0, 0.4, 2.2, 1.0], 0.825, 1.044],
#  [[0.5, 5.0, 0.4, 2.3, 1.0], 0.825, 1.044],
#  [[0.5, 5.0, 0.4, 2.8, 1.0], 0.825, 1.041],
#  [[0.5, 3.0, 0.4, 2.8, 1.3], 0.778, 1.04],
#  [[0.5, 3.0, 0.4, 2.9, 1.3], 0.778, 1.04],
#  [[0.5, 3.0, 0.4, 3.0, 1.3], 0.778, 1.04],
#  [[0.5, 3.0, 0.3, 2.4, 1.2], 0.762, 1.038],
#  [[0.5, 3.0, 0.3, 2.5, 1.2], 0.762, 1.038],
#  [[0.5, 3.0, 0.3, 2.6, 1.2], 0.762, 1.038],
#  [[0.5, 3.0, 0.3, 2.7, 1.2], 0.762, 1.038],
#  [[0.5, 3.0, 0.3, 2.8, 1.2], 0.762, 1.038],
#  [[0.5, 3.0, 0.3, 2.9, 1.2], 0.762, 1.038],
#  [[0.5, 3.0, 0.3, 3.0, 1.2], 0.762, 1.038],
#  [[0.5, 3.0, 0.4, 2.6, 1.1], 0.668, 1.038],
#  [[0.5, 3.0, 0.4, 2.7, 1.1], 0.668, 1.038],
#  [[0.5, 3.0, 0.4, 2.8, 1.1], 0.668, 1.038],
#  [[0.5, 3.0, 0.4, 2.9, 1.1], 0.668, 1.038],
#  [[0.5, 3.0, 0.4, 3.0, 1.1], 0.668, 1.038],
#  [[0.5, 3.0, 0.4, 2.0, 1.2], 0.782, 1.037],
#  [[0.5, 3.0, 0.4, 2.1, 1.2], 0.782, 1.037],
#  [[0.5, 3.0, 0.4, 2.2, 1.2], 0.782, 1.037],
#  [[0.5, 3.0, 0.4, 2.3, 1.2], 0.782, 1.037],
#  [[0.5, 5.0, 0.1, 2.2, 1.0], 0.907, 1.037],
#  [[0.5, 3.0, 0.3, 2.3, 1.2], 0.762, 1.036],
#  [[0.5, 3.0, 0.5, 2.3, 1.2], 0.772, 1.033],
#  [[0.5, 3.0, 0.5, 2.4, 1.2], 0.772, 1.033],
#  [[0.5, 3.0, 0.5, 2.5, 1.2], 0.772, 1.033],
#  [[0.5, 3.0, 0.5, 2.6, 1.2], 0.772, 1.033],
#  [[0.5, 3.0, 0.5, 2.7, 1.2], 0.772, 1.033],
#  [[0.5, 3.0, 0.5, 2.8, 1.2], 0.772, 1.033],
#  [[0.5, 3.0, 0.5, 2.9, 1.2], 0.772, 1.033],
#  [[0.5, 3.0, 0.5, 3.0, 1.2], 0.772, 1.033],
#  [[0.5, 3.0, 0.3, 2.0, 1.2], 0.762, 1.033],
#  [[0.5, 3.0, 0.3, 2.1, 1.2], 0.762, 1.033],
#  [[0.5, 5.0, 0.3, 3.0, 1.0], 0.871, 1.033],
#  [[0.5, 5.0, 0.1, 2.3, 1.0], 0.907, 1.032],
#  [[0.5, 5.0, 0.1, 2.4, 1.0], 0.907, 1.032],
#  [[0.5, 5.0, 0.1, 2.5, 1.0], 0.907, 1.032],
#  [[0.5, 5.0, 0.1, 2.6, 1.0], 0.907, 1.032],
#  [[0.5, 5.0, 0.1, 2.7, 1.0], 0.907, 1.032],
#  [[0.5, 5.0, 0.1, 2.8, 1.0], 0.907, 1.032],
#  [[0.5, 5.0, 0.1, 2.9, 1.0], 0.907, 1.032],
#  [[0.5, 5.0, 0.1, 3.0, 1.0], 0.907, 1.032],
#  [[0.5, 5.0, 0.5, 2.3, 1.0], 0.902, 1.032],
#  [[0.5, 5.0, 0.3, 2.8, 1.0], 0.871, 1.029],
#  [[0.5, 5.0, 0.5, 2.7, 1.0], 0.902, 1.028],
#  [[0.5, 3.0, 0.2, 2.2, 1.4], 0.65, 1.027],
#  [[0.5, 5.0, 0.3, 2.2, 1.5], 0.879, 1.027],
#  [[0.5, 5.0, 0.3, 2.3, 1.5], 0.879, 1.027],
#  [[0.5, 5.0, 0.3, 2.4, 1.5], 0.879, 1.027],
#  [[0.5, 5.0, 0.3, 2.5, 1.5], 0.879, 1.027],
#  [[0.5, 5.0, 0.3, 2.6, 1.5], 0.879, 1.027],
#  [[0.5, 5.0, 0.3, 2.7, 1.5], 0.879, 1.027],
#  [[0.5, 5.0, 0.3, 2.8, 1.5], 0.879, 1.027],
#  [[0.5, 5.0, 0.3, 2.9, 1.5], 0.879, 1.027],
#  [[0.5, 5.0, 0.3, 3.0, 1.5], 0.879, 1.027],
#  [[0.5, 5.0, 0.5, 2.0, 1.0], 0.902, 1.026],
#  [[0.5, 3.0, 0.5, 2.4, 1.4], 0.7, 1.025],
#  [[0.5, 3.0, 0.5, 2.5, 1.4], 0.7, 1.025],
#  [[0.5, 3.0, 0.5, 2.6, 1.4], 0.7, 1.025],
#  [[0.5, 3.0, 0.5, 2.7, 1.4], 0.7, 1.025],
#  [[0.5, 3.0, 0.5, 2.8, 1.4], 0.7, 1.025],
#  [[0.5, 3.0, 0.5, 2.9, 1.4], 0.7, 1.025],
#  [[0.5, 3.0, 0.5, 3.0, 1.4], 0.7, 1.025],
#  [[0.5, 5.0, 0.3, 2.4, 1.0], 0.871, 1.025],
#  [[0.5, 5.0, 0.5, 2.2, 1.0], 0.902, 1.024],
#  [[0.5, 5.0, 0.4, 2.1, 1.0], 0.825, 1.02],
#  [[0.5, 5.0, 0.5, 2.9, 1.0], 0.902, 1.02],
#  [[0.5, 5.0, 0.5, 3.0, 1.0], 0.902, 1.02],
#  [[0.5, 5.0, 0.5, 2.9, 1.7], 0.809, 1.02],
#  [[0.5, 5.0, 0.5, 3.0, 1.7], 0.809, 1.02],
#  [[0.5, 5.0, 0.5, 2.4, 1.7], 0.809, 1.02],
#  [[0.5, 5.0, 0.5, 2.6, 1.7], 0.861, 1.02]]

# %% [markdown]
# ## Min based overall

# %%
pprint(list(sorted(ans, key=lambda x:-x[-2]))[:30])
# Out:
# [[[0.5, 5.0, 0.5, 2.0, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.1, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.2, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.3, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.4, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.5, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.6, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.7, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.8, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 2.9, 1.1], 1.271, 1.778],
#  [[0.5, 5.0, 0.5, 3.0, 1.1], 1.271, 1.778],
#  [[0.5, 3.0, 0.5, 2.0, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.1, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.2, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.3, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.4, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.5, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.6, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.7, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.8, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 2.9, 1.1], 1.163, 1.649],
#  [[0.5, 3.0, 0.5, 3.0, 1.1], 1.163, 1.649],
#  [[0.5, 5.0, 0.1, 2.0, 1.2], 1.015, 1.23],
#  [[0.5, 5.0, 0.1, 2.1, 1.2], 1.015, 1.23],
#  [[0.5, 5.0, 0.1, 2.2, 1.2], 1.015, 1.23],
#  [[0.5, 5.0, 0.1, 2.3, 1.2], 1.015, 1.23],
#  [[0.5, 5.0, 0.1, 2.0, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.1, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.2, 1.3], 1.013, 1.233],
#  [[0.5, 5.0, 0.1, 2.3, 1.3], 1.013, 1.233]]
